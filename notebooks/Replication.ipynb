# %%
import fasttext
import numpy as np
from huggingface_hub import hf_hub_download
import pandas as pd
import json

# %%
#Load OpenLID Model
# open_model_path = hf_hub_download(repo_id="/Users/yvon/dat/LangIds/OpenLID/", filename="lid201_model.bin")
open_model_path = "/Users/yvon/dat/LangId/OpenLID/lid201-model.ftz"
open_model = fasttext.load_model(open_model_path)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
#Checking Labeling in OpenLID
print(f"Number of Languages in OpenLID: {len(open_model.get_labels())}")
the_labels = open_model.get_labels()
[label for label in the_labels if "eu" in label or "es" in label or "spa" in label or 'eng' in label or 'tur' in label]
# Out:
# Number of Languages in OpenLID: 201
# ['__label__eng_Latn',
#  '__label__est_Latn',
#  '__label__pes_Arab',
#  '__label__tur_Latn',
#  '__label__spa_Latn',
#  '__label__deu_Latn',
#  '__label__eus_Latn',
#  '__label__ben_Beng',
#  '__label__ces_Latn',
#  '__label__asm_Beng',
#  '__label__mni_Beng']

# %%
#Load GlotLID Model
# glot_model_path = hf_hub_download(repo_id="/Users/yvon/dat/LangIds/GlotLID/", filename="model_v3.bin", cache_dir=None)
glot_model_path = "/Users/yvon/dat/LangId/GlotLID/model_v3.bin"
glot_model = fasttext.load_model(glot_model_path)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
#Checking Labeling in GlotLID
print(f"Number of Languages in GlotLID: {len(glot_model.get_labels())}")
the_labels = glot_model.get_labels()
[label for label in the_labels if "eu" in label or "es" in label or "spa" in label]
# Out:
# Number of Languages in GlotLID: 2102
# ['__label__spa_Latn',
#  '__label__deu_Latn',
#  '__label__ces_Latn',
#  '__label__eus_Latn',
#  '__label__meu_Latn',
#  '__label__wes_Latn',
#  '__label__ese_Latn',
#  '__label__ses_Latn',
#  '__label__leu_Latn',
#  '__label__des_Latn',
#  '__label__esk_Latn',
#  '__label__aeu_Latn',
#  '__label__esu_Latn',
#  '__label__esi_Latn',
#  '__label__ess_Latn']

# %%
#Load MaskLID
import sys
sys.path.append("/Users/yvon/CNRS-DRIVE/Code/MaskLID.LMU")

from masklid import MaskLID
# mask_model_path = './model_v3.bin' #GlotLID basis(GLOTLid Latest version so it has 2000+ languages)
mask_base_glot_model = glot_model
mask_model_path = glot_model_path

masklid_model = MaskLID(mask_model_path , languages = -1)
print(len(mask_base_glot_model.get_labels()))
# Out:
# 2102
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %% [markdown]
# TURKISH ENGLISH DATASET

# %%
# Test data path : 
csdata_path = "/Users/yvon/dat/Projects/Code-Switching/"

with open(csdata_path + "tur-eng/TR-EN CS Corpus - with language tags.txt", encoding="utf-8") as f:
    blocks = f.read().strip().split("\n\n")

# print(blocks)
print(f"number of all sentences :{len(blocks)}")

df_rows = []
cs_blocks= [] #saving the tokens with labels (t/e) for masking

non_cs_blocks = []

tr_only_sentences =[]

for block in blocks:
    lines = block.strip().split("\n")
    tokens = [line.split()[0] for line in lines if line.strip()]
    langs = set(("__label__tur_Latn" if line.split()[1] =="t" else "__label__eng_Latn") for line in lines if line.strip())
    sentence = " ".join(tokens)
   
    if langs =={"__label__tur_Latn","__label__eng_Latn"}:
        df_rows.append({"Text": sentence, "True Labels": langs})
        cs_blocks.append(lines)
    else:
        non_cs_blocks.append({"Text":sentence, "True Labels": langs})
        
    df_tr_eng = pd.DataFrame(df_rows)
    df_mon = pd.DataFrame(non_cs_blocks)


for lines in cs_blocks:
    tr_tokens = [line.split()[0] for line in lines if line.strip() and line.split()[1] =="t"]
    sentence = " ".join(tr_tokens)
    tr_only_sentences.append(sentence)

    df_tr_only = pd.DataFrame({"Text": tr_only_sentences, "True Labels": [{"__label__tur_Latn"}] * len(tr_only_sentences)})


#Set whether want to see the full df or not
# pd.reset_option("display.max_colwidth", None)


#see a full row 
# print(df_tr_eng.loc[2, "Text"])

# print(df_tr_eng.head(5))
print(f"Number of cs sentences :{len(df_tr_eng)}")


# print(df_mon)
print(f"Number of monolingual sentences : {len(non_cs_blocks)}")


# print(df_tr_only.head(5))
print(f"Number of turkish only sentences : {len(df_tr_only)}")
# Out:
# number of all sentences :377
# Number of cs sentences :372
# Number of monolingual sentences : 5
# Number of turkish only sentences : 372

# %% [markdown]
# BASQ-SPANISH DATASET

# %%
# Load file JSON
file_path = csdata_path + "eus-spa/valid_utterances.json"
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Save data into a separate list
cs_rows = []
basque_rows = []
spanish_rows = []

for entry in data:
    # Take the code-switching sentence
    for cs_example in entry.get("code-switching", []):
        text = cs_example["text"]
        # lang_label = cs_example["lang_proportion"]
        cs_rows.append((text, {"__label__eus_Latn","__label__spa_Latn"}))

    # Get pure sentences from 'referent' based on source_lang
    if entry["source_lang"] == "eu":
        basque_rows.append((entry["referent"], {"__label__eus_Latn"}))
    elif entry["source_lang"] == "es":
        spanish_rows.append((entry["referent"], {"__label__spa_Latn"}))

# Convert to DataFrame
df_basq_spanish = pd.DataFrame(cs_rows, columns=["Text", "True Labels"])
df_eu = pd.DataFrame(basque_rows, columns=["Text", "True Labels"])
df_es = pd.DataFrame(spanish_rows, columns=["Text", "True Labels"])

# Combine everything
df_all = pd.concat([df_basq_spanish, df_eu, df_es], ignore_index=True)

# Check the results
print("Number of sentences code-switching:", len(df_basq_spanish))
print("Number of sentencesv Basque:", len(df_eu))
print("Number of sentences Spanish:", len(df_es))
# print(df_all.sample(5))

df_es.head(5)
# Out:
# Number of sentences code-switching: 1377
# Number of sentencesv Basque: 449
# Number of sentences Spanish: 478
#                                                 Text          True Labels
# 0  es la web una de las formas para pedir las cla...  {__label__spa_Latn}
# 1          hola, quiero subvenciones dentro de plazo  {__label__spa_Latn}
# 2                          dame el listado de ayudas  {__label__spa_Latn}
# 3                               va a seguir nublado?  {__label__spa_Latn}
# 4  quiero saber si le vais a enviar las claves a ...  {__label__spa_Latn}

# %% [markdown]
# HINDI-ENGLISH DATASET

# %%
import pandas as pd

def parse_hineng(path):
    with open(path, encoding="utf-8") as f:
        content = f.read().strip().split("# sent_enum = ")
        blocks = [b for b in content if b.strip()]

    cs_rows, en_rows, hi_rows = [], [], []

    for block in blocks:
        tokens = []
        langs = set()

        lines = [line for line in block.splitlines() if line.strip()]

        for line in lines[1:]:
            parts = line.strip().split()
            if len(parts) != 2:
                continue

            token, lang = parts

            if lang == "lang1":
                tokens.append(token)
                langs.add("__label__eng_Latn")
            elif lang == "lang2":
                tokens.append(token)
                langs.add("__label__hin_Deva")

        if not tokens:
            continue

        sentence = " ".join(tokens)

        if langs == {"__label__eng_Latn", "__label__hin_Deva"}:
            cs_rows.append((sentence, langs))
        elif langs == {"__label__eng_Latn"}:
            en_rows.append((sentence, langs))
        elif langs == {"__label__hin_Deva"}:
            hi_rows.append((sentence, langs))

    return cs_rows, en_rows, hi_rows


# file_path = csdata_path + "hin-eng/lince_lid_en-hi_train.conll"
file_path = csdata_path + "hin-eng/lince_lid_en-hi_dev.conll"
cs_rows, en_rows, hi_rows = parse_hineng(file_path)

df_he = pd.DataFrame(cs_rows, columns=["Text", "True Labels"])
df_en1 = pd.DataFrame(en_rows, columns=["Text", "True Labels"])
df_h = pd.DataFrame(hi_rows, columns=["Text", "True Labels"])

print(f"Hindi-English (code-switched) : {len(df_he)}")
print(f"English only                  : {len(df_en1)}")
print(f"Hindi only                    : {len(df_h)}")
# Out:
# Hindi-English (code-switched) : 322
# English only                  : 386
# Hindi only                    : 31

# %% [markdown]
# NEPALI-ENGLISH DATASET

# %%
import pandas as pd

def parse(path):
    with open(path, encoding="utf-8") as f:
        content = f.read().strip().split("# sent_enum = ")
        blocks = [b for b in content if b.strip()]

    cs_rows, en_rows, np_rows = [], [], []

    for block in blocks:
        tokens = []
        langs = set()

        lines = [line for line in block.splitlines() if line.strip()]

        for line in lines[1:]:
            parts = line.strip().split()
            if len(parts) != 2:
                continue

            token, lang = parts

            if lang == "lang1":
                tokens.append(token)
                langs.add("__label__eng_Latn")
            elif lang == "lang2":
                tokens.append(token)
                langs.add("__label__npi_Deva")

        if not tokens:
            continue

        sentence = " ".join(tokens)

        if langs == {"__label__eng_Latn", "__label__npi_Deva"}:
            cs_rows.append((sentence, langs))
        elif langs == {"__label__eng_Latn"}:
            en_rows.append((sentence, langs))
        elif langs == {"__label__npi_Deva"}:
            np_rows.append((sentence, langs))

    return cs_rows, en_rows, np_rows

# Uji coba
# file_path = csdata_path + "nep-eng/lince_lid_en-ne_train.conll"
file_path = csdata_path + "nep-eng/lince_lid_en-ne_dev.conll"
cs_rows, en_rows, np_rows = parse(file_path)

df_ne = pd.DataFrame(cs_rows, columns=["Text", "True Labels"])
df_en2 = pd.DataFrame(en_rows, columns=["Text", "True Labels"])
df_n = pd.DataFrame(np_rows, columns=["Text", "True Labels"])

print(f"Code-switched : {len(df_ne)}")
print(f"English only  : {len(df_en2)}")
print(f"Nepali only   : {len(df_n)}")

print("\nContoh baris dari Nepali only:")
print(df_ne.head(3))
# Out:
# Code-switched : 943
# English only  : 172
# Nepali only   : 217
#
# Contoh baris dari Nepali only:
#                                                 Text  \
# 0  la hamlai bhetna paayeko will be your greatest...
# 1  areyy thahrachha j hos I told ya I am a good o...
# 2                          Nindra is on date I guess
#
#                               True Labels
# 0  {__label__npi_Deva, __label__eng_Latn}
# 1  {__label__npi_Deva, __label__eng_Latn}
# 2  {__label__npi_Deva, __label__eng_Latn}

# %% [markdown]
# ENGLISH ONLY

# %%
df_e = pd.concat([df_en1, df_en2], ignore_index=True)

print(f"Final English Only : {len(df_e)}")
# Out:
# Final English Only : 558

# %% [markdown]
# PREPROCESSING

# %%
# df_te = df_tr_eng.copy()
# df_t = df_tr_only.copy()
# df_bs = df_basq_spanish.copy()
# df_b = df_eu.copy()
# df_s = df_es.copy()

# df_he = df_he.copy()
# df_h = df_h.copy()
# df_ne = df_ne.copy()
# df_n = df_n.copy()
# df_e = df_e.copy()

# import re
# import unicodedata
# from sacremoses import MosesPunctNormalizer
# import emoji

# # Patterns mirip di paper MaskLID
# URL_PATTERN = re.compile(r'https?://\S+|www\.\S+')
# HASHTAG_PATTERN = re.compile(r'#\w+')
# MENTION_PATTERN = re.compile(r'@\w+')
# RESERVED_WORDS_PATTERN = re.compile(r'\b(RT|FAV|VIA)\b', re.IGNORECASE)
# NUMBERS_PATTERN = re.compile(r'\b\d+\b')

# mpn = MosesPunctNormalizer(lang='en')

# def remove_non_printing(text):
#     return ''.join(c if c.isprintable() else ' ' for c in text)

# def clean_1(text):
#     text = mpn.normalize(text)
#     text = remove_non_printing(text)
#     text = unicodedata.normalize("NFKC", text)
#     text = emoji.replace_emoji(text, "")
#     text = text.lower()  # optional, tergantung config asli
#     text = URL_PATTERN.sub('', text)
#     text = HASHTAG_PATTERN.sub('', text)
#     text = MENTION_PATTERN.sub('', text)
#     text = RESERVED_WORDS_PATTERN.sub('', text)
#     text = NUMBERS_PATTERN.sub('', text)
#     text = ' '.join(text.strip().split())  # normalisasi spasi
#     return text

# def byte_len(text):
#     return len(text.encode("utf-8"))

# #Apply Cleaning
# df_te["Text"] = df_te["Text"].apply(clean_1)
# df_t["Text"] = df_t["Text"].apply(clean_1)
# df_bs["Text"] = df_bs["Text"].apply(clean_1)
# df_b["Text"] = df_b["Text"].apply(clean_1)
# df_s["Text"] = df_s["Text"].apply(clean_1)

# df_ne["Text"] = df_ne["Text"].apply(clean_1)
# df_n["Text"] = df_n["Text"].apply(clean_1)
# df_he["Text"] = df_he["Text"].apply(clean_1)
# df_h["Text"] = df_h["Text"].apply(clean_1)
# df_e["Text"] = df_e["Text"].apply(clean_1)

# # Filter based on byte-length
# df_te = df_te[df_te["Text"].apply(byte_len) > 40]
# df_t = df_t[df_t["Text"].apply(byte_len) > 20]
# df_bs = df_bs[df_bs["Text"].apply(byte_len) > 40]
# df_b = df_b[df_b["Text"].apply(byte_len) > 20]
# df_s = df_s[df_s["Text"].apply(byte_len) > 20]

# df_he = df_he[df_he["Text"].apply(byte_len)>40]
# df_n = df_n[df_n["Text"].apply(byte_len)>20]
# df_ne = df_ne[df_ne["Text"].apply(byte_len)>40]
# df_n = df_n[df_n["Text"].apply(byte_len)>20]
# df_e = df_e[df_e["Text"].apply(byte_len)>20]


# print(f"Turkish-English : {len(df_te)}")
# print(f"Basque-Spanish : {len(df_bs)}")

# print(f"Hindi-English: {len(df_he)}")
# print(f"Nepali-English: {len(df_ne)}")

# print(f"Basque Only : {len(df_b)}")
# print(f"Spanish Only : {len(df_s)}")
# print(f"Turkish Only : {len(df_t)}")

# print(f"Hindi Only: {len(df_h)}")
# print(f"Nepali Only: {len(df_n)}")
# print(f"English Only: {len(df_e)}")

# %%
#data-preprocess
df_te = df_tr_eng.copy()
df_t = df_tr_only.copy()
df_bs = df_basq_spanish.copy()
df_b = df_eu.copy()
df_s = df_es.copy()

df_he = df_he.copy()
df_h = df_h.copy()
df_ne = df_ne.copy()
df_n = df_n.copy()
df_e = df_e.copy()


import re
import unicodedata
# from sacremoses import MosesPunctNormalizer
# import emoji

# Patterns mirip di paper MaskLID
URL_PATTERN = re.compile(r'https?://\S+|www\.\S+')
HASHTAG_PATTERN = re.compile(r'#\w+')
MENTION_PATTERN = re.compile(r'@\w+')
RESERVED_WORDS_PATTERN = re.compile(r'\b(RT|FAV|VIA)\b', re.IGNORECASE)
NUMBERS_PATTERN = re.compile(r'\b\d+\b')

# mpn = MosesPunctNormalizer(lang='en')

def remove_non_printing(text):
    return ''.join(c if c.isprintable() else ' ' for c in text)

def clean_1(text):
    text = text.lower()  
    text = ' '.join(text.strip().split())  
    return text

def byte_len(text):
    return len(text.encode("utf-8"))

#Apply Cleaning
df_te["Text"] = df_te["Text"].apply(clean_1)
df_t["Text"] = df_t["Text"].apply(clean_1)
df_bs["Text"] = df_bs["Text"].apply(clean_1)
df_b["Text"] = df_b["Text"].apply(clean_1)
df_s["Text"] = df_s["Text"].apply(clean_1)

df_ne["Text"] = df_ne["Text"].apply(clean_1)
df_n["Text"] = df_n["Text"].apply(clean_1)
df_he["Text"] = df_he["Text"].apply(clean_1)
df_h["Text"] = df_h["Text"].apply(clean_1)
df_e["Text"] = df_e["Text"].apply(clean_1)

# Filter based on byte-length
df_te = df_te[df_te["Text"].apply(byte_len) > 40]
df_t = df_t[df_t["Text"].apply(byte_len) > 20]
df_bs = df_bs[df_bs["Text"].apply(byte_len) > 40]
df_b = df_b[df_b["Text"].apply(byte_len) > 20]
df_s = df_s[df_s["Text"].apply(byte_len) > 20]

df_he = df_he[df_he["Text"].apply(byte_len)>40]
df_n = df_n[df_n["Text"].apply(byte_len)>20]
df_ne = df_ne[df_ne["Text"].apply(byte_len)>40]
df_n = df_n[df_n["Text"].apply(byte_len)>20]
df_e = df_e[df_e["Text"].apply(byte_len)>20]


print(f"Turkish-English : {len(df_te)}")
print(f"Basque-Spanish : {len(df_bs)}")

print(f"Hindi-English: {len(df_he)}")
print(f"Nepali-English: {len(df_ne)}")

print(f"Basque Only : {len(df_b)}")
print(f"Spanish Only : {len(df_s)}")
print(f"Turkish Only : {len(df_t)}")

print(f"Hindi Only: {len(df_h)}")
print(f"Nepali Only: {len(df_n)}")
print(f"English Only: {len(df_e)}")
# Out:
# Turkish-English : 339
# Basque-Spanish : 446
# Hindi-English: 235
# Nepali-English: 623
# Basque Only : 357
# Spanish Only : 356
# Turkish Only : 341
# Hindi Only: 31
# Nepali Only: 177
# English Only: 476

# %%
df_te.to_csv("df_te.csv", index=False)
df_t.to_csv("df_turk.csv", index=False)
# df_bs.to_csv("df_bs.csv", index=False)
# df_basq.to_csv("df_basq.csv", index=False)
# df_span.to_csv("df_span.csv", index=False)
# df_he.to_csv("df_he.csv", index=False)
# df_n.to_csv("df_n.csv", index=False)
# df_ne.to_csv("df_ne.csv", index=False)
# df_n.to_csv("df_n.csv", index=False)
# df_e.to_csv("df_e.csv", index=False)

# %% [markdown]
# MATRIX PERFORMANCE

# %% [markdown]
# MONO

# %%
def em_pm_mono(y_true, y_pred):
    em = 0
    pm = 0

    for true_set, pred_set in zip(y_true, y_pred):
        if pred_set == true_set:
            em += 1
            pm += 1  # EM is always also PM

        elif pred_set & true_set:
            # Overlap exists, but not exact match
            pm += 1

    return em, pm

# %% [markdown]
# CS

# %%
def em_pm_cs(y_true, y_pred):
    em = 0
    pm = 0

    for gold, pred in zip(y_true, y_pred):
        if pred == gold:
            em += 1
            pm += 1
        elif len(pred) == 1 and next(iter(pred)) in gold:
            # predicted exactly one of the two languages
            pm += 1

    return em, pm

# %%
def count_fp(y_true, y_pred):
    fp = 0
    for true_set, pred_set in zip(y_true, y_pred):
        if len(pred_set) > 1:  # CS only
            if len(true_set - pred_set) == 1 :
                fp += 1
    return fp

# %%
df_eval = pd.concat([
    df_te.assign(Type='cs'),
    df_bs.assign(Type='cs'),
    df_he.assign(Type='cs'),
    df_ne.assign(Type='cs'),
    
    df_t.assign(Type='mono'),
    df_b.assign(Type='mono'),
    df_s.assign(Type='mono'),
    df_h.assign(Type='mono'),
    df_n.assign(Type='mono'),
    df_e.assign(Type='mono')
])

df_eval_o = df_eval.copy()
df_eval_g = df_eval.copy()
df_eval_om = df_eval.copy()
df_eval_gm = df_eval.copy()

# %% [markdown]
# 1. OpenLID ONLY

# %%
# pd.set_option("display.max_colwidth", None)
def open_lid(text):
    labels, probs = open_model.predict(text, k=2)
    probs = np.asarray(probs) #convert probs to safe format
    return {label for label,prob in zip(labels,probs) if prob>= 0.3}
    
def apply_open_lid(df):
    df['Pred'] = df['Text'].apply(open_lid)
        
    return df

# %%
# Apply model to all data
df_eval_o = apply_open_lid(df_eval_o)  # results are stored in 'Predicted Labels'

# Normalize the ground truth label column to set
df_eval_o["True Labels"] = df_eval_o["True Labels"].apply(lambda x: set(x) if isinstance(x, list) or isinstance(x, set) else set(x.split()))

# %% [markdown]
# MONO-ENGLISH

# %%
subset_e_o  = df_eval_o[df_eval_o["True Labels"].apply(lambda x: x in df_e["True Labels"].values)]    # Mono English

em_e_o, pm_e_o = em_pm_mono(subset_e_o["True Labels"], subset_e_o["Pred"])

# Output hasil
print(f"#EM: {em_e_o}")
print(f"#PM: {pm_e_o}")
# Out:
# #EM: 427
# #PM: 436

# %% [markdown]
# TURKISH-ENGLISH EVAL

# %%
subset_te_o = df_eval_o[df_eval_o["True Labels"].apply(lambda x: x in df_te["True Labels"].values)]
subset_t_o  = df_eval_o[df_eval_o["True Labels"].apply(lambda x: x in df_t["True Labels"].values)]

# CS Turkish–English: EM / PM
em_te_o, pm_te_o = em_pm_cs(subset_te_o["True Labels"], subset_te_o["Pred"])

# Calculate FP (for CS only)
fp_te_o = count_fp(subset_te_o["True Labels"], subset_te_o["Pred"])

# Mono Turkish: EM / PM
em_t_o, pm_t_o = em_pm_mono(subset_t_o["True Labels"], subset_t_o["Pred"])

# Output hasil
print(f"#EM: {em_te_o}")
print(f"#PM: {pm_te_o}")
print(f"#FP: {fp_te_o}")
# Out:
# #EM: 0
# #PM: 318
# #FP: 3

# %% [markdown]
# BASQ-SPANISH EVAL

# %%
#Making Subset to Filter Only ["True Labels"] and its ["Pred"] from df_eval
subset_bs_o = df_eval_o[df_eval_o["True Labels"].apply(lambda x: x in df_bs["True Labels"].values)]  # CS Basque–Spanish
subset_b_o  = df_eval_o[df_eval_o["True Labels"].apply(lambda x: x in df_b["True Labels"].values)]   # Mono Basque
subset_s_o  = df_eval_o[df_eval_o["True Labels"].apply(lambda x: x in df_s["True Labels"].values)]   # Mono Spanish

#CS Basque-Spanish EM/PM
em_bs_o, pm_bs_o = em_pm_cs(subset_bs_o["True Labels"], subset_bs_o["Pred"])

# Calculate FP (for CS only)
fp_bs_o = count_fp(subset_bs_o["True Labels"], subset_bs_o["Pred"])

#Mono Basque EM/PM
em_b_o, pm_b_o = em_pm_mono(subset_b_o["True Labels"], subset_b_o["Pred"])

#Mono Spanish EM/PM
em_s_o, pm_s_o = em_pm_mono(subset_s_o["True Labels"], subset_s_o["Pred"])

print(f"#EM: {em_bs_o}")
print(f"#PM: {pm_bs_o}")
print(f"#FP: {fp_bs_o}")
# Out:
# #EM: 9
# #PM: 423
# #FP: 6

# %% [markdown]
# HINDI-ENGLISH EVAL

# %%
subset_he_o = df_eval_o[df_eval_o["True Labels"].apply(lambda x: x in df_he["True Labels"].values)]  
subset_h_o  = df_eval_o[df_eval_o["True Labels"].apply(lambda x: x in df_h["True Labels"].values)]   

# EM / PM for CS Hindi–English
em_he_o, pm_he_o = em_pm_cs(subset_he_o["True Labels"], subset_he_o["Pred"])

# Calculate FP (for CS only)
fp_he_o = count_fp(subset_he_o["True Labels"], subset_he_o["Pred"])

# EM / PM for mono Hindi
em_h_o, pm_h_o = em_pm_mono(subset_h_o["True Labels"], subset_h_o["Pred"])

print(f"#EM: {em_he_o}")
print(f"#PM: {pm_he_o}")
# print(f"#FP: {fp_he}")
# Out:
# #EM: 0
# #PM: 80

# %% [markdown]
# NEPALI-ENGLISH EVAL

# %%
subset_ne_o = df_eval_o[df_eval_o["True Labels"].apply(lambda x: x in df_ne["True Labels"].values)]   # CS Nepali–English
subset_n_o  = df_eval_o[df_eval_o["True Labels"].apply(lambda x: x in df_n["True Labels"].values)]    # Mono Nepali

# EM / PM for CS Nepali–English
em_ne_o, pm_ne_o = em_pm_cs(subset_ne_o["True Labels"], subset_ne_o["Pred"])

# FP from mono Nepali/English predicted to be CS pair
fp_ne_o = count_fp(subset_ne_o["True Labels"], subset_ne_o["Pred"])

# EM/PM for Nepali mono
em_n_o, pm_n_o = em_pm_mono(subset_n_o["True Labels"], subset_n_o["Pred"])

print(f"#EM: {em_he_o}")
print(f"#PM: {pm_he_o}")
# print(f"#FP: {fp_he}")
# Out:
# #EM: 0
# #PM: 80

# %% [markdown]
# 2. GlotLID ONLY

# %%
#Cutom Model Class for Customizing GlotLID
import fasttext
import numpy as np
class CustomLID:
    def __init__(self, model_path, languages = -1, mode='before'):
        self.model = fasttext.load_model(model_path)
        self.output_matrix = self.model.get_output_matrix()
        self.labels = self.model.get_labels()
        
        # compute language_indices
        if languages !=-1 and isinstance(languages, list):
            self.language_indices = [self.labels.index(l) for l in list(set(languages)) if l in self.labels]

        else:
            self.language_indices = list(range(len(self.labels)))

        # limit labels to language_indices
        self.labels = list(np.array(self.labels)[self.language_indices])
        
        # predict
        self.predict = self.predict_limit_after_softmax if mode=='after' else self.predict_limit_before_softmax

    
    def predict_limit_before_softmax(self, text, k=1):
        
        # sentence vector
        sentence_vector = self.model.get_sentence_vector(text)
        
        # dot
        result_vector = np.dot(self.output_matrix[self.language_indices, :], sentence_vector)

        # softmax
        softmax_result = np.exp(result_vector - np.max(result_vector)) / np.sum(np.exp(result_vector - np.max(result_vector)))

        # top k predictions
        top_k_indices = np.argsort(softmax_result)[-k:][::-1]
        top_k_labels = [self.labels[i] for i in top_k_indices]
        top_k_probs = softmax_result[top_k_indices]

        return tuple(top_k_labels), top_k_probs


    def predict_limit_after_softmax(self, text, k=1):
        
        # sentence vector
        sentence_vector = self.model.get_sentence_vector(text)
        
        # dot
        result_vector = np.dot(self.output_matrix, sentence_vector)

        # softmax
        softmax_result = np.exp(result_vector - np.max(result_vector)) / np.sum(np.exp(result_vector - np.max(result_vector)))

        # limit softmax to language_indices
        softmax_result = softmax_result[self.language_indices]

        # top k predictions
        top_k_indices = np.argsort(softmax_result)[-k:][::-1]
        top_k_labels = [self.labels[i] for i in top_k_indices]
        top_k_probs = softmax_result[top_k_indices]

        return tuple(top_k_labels), top_k_probs

# %%
#list 200 restricted languages for GlotLID
flores_glotlid = ['__label__eng_Latn', '__label__arb_Arab', '__label__rus_Cyrl', '__label__por_Latn', '__label__pol_Latn', '__label__ekk_Latn', '__label__ell_Grek', '__label__slk_Latn', '__label__slv_Latn', '__label__nld_Latn', '__label__lvs_Latn', '__label__hun_Latn', '__label__dan_Latn', '__label__swe_Latn', '__label__lit_Latn', '__label__fin_Latn', '__label__mlt_Latn', '__label__cmn_Hani', '__label__nob_Latn', '__label__kor_Hang', '__label__ind_Latn', '__label__uzn_Latn', '__label__fil_Latn', '__label__ukr_Cyrl', '__label__hin_Deva', '__label__hin_Latn', '__label__afr_Latn', '__label__mar_Deva', '__label__ceb_Latn', '__label__ilo_Latn', '__label__zul_Latn', '__label__heb_Hebr', '__label__xho_Latn', '__label__vie_Latn', '__label__jpn_Jpan', '__label__guj_Gujr', '__label__hrv_Latn', '__label__tur_Latn', '__label__nya_Latn', '__label__tsn_Latn', '__label__sna_Latn', '__label__tso_Latn', '__label__tha_Thai', '__label__spa_Latn', '__label__deu_Latn', '__label__eus_Latn', '__label__bul_Cyrl', '__label__amh_Ethi', '__label__fra_Latn', '__label__ewe_Latn', '__label__mkd_Cyrl', '__label__nso_Latn', '__label__tam_Taml', '__label__lin_Latn', '__label__twi_Latn', '__label__yor_Latn', '__label__als_Latn', '__label__ibo_Latn', '__label__ben_Beng', '__label__ita_Latn', '__label__tpi_Latn', '__label__azj_Latn', '__label__run_Latn', '__label__mya_Mymr', '__label__kin_Latn', '__label__ron_Latn', '__label__ces_Latn', '__label__kat_Geor', '__label__urd_Arab', '__label__zsm_Latn', '__label__pap_Latn', '__label__bem_Latn', '__label__mal_Mlym', '__label__kir_Cyrl', '__label__hye_Armn', '__label__smo_Latn', '__label__sin_Sinh', '__label__fij_Latn', '__label__kan_Knda', '__label__pan_Guru', '__label__hau_Latn', '__label__epo_Latn', '__label__gaz_Latn', '__label__tir_Ethi', '__label__bos_Latn', '__label__srp_Cyrl', '__label__hat_Latn', '__label__pag_Latn', '__label__lua_Latn', '__label__war_Latn', '__label__tel_Telu', '__label__tat_Cyrl', '__label__sag_Latn', '__label__lug_Latn', '__label__tum_Latn', '__label__swh_Latn', '__label__umb_Latn', '__label__som_Latn', '__label__gle_Latn', '__label__kng_Latn', '__label__mos_Latn', '__label__lus_Latn', '__label__khk_Cyrl', '__label__asm_Beng', '__label__tuk_Latn', '__label__quy_Latn', '__label__ayr_Latn', '__label__luo_Latn', '__label__tgk_Cyrl', '__label__cat_Latn', '__label__ssw_Latn', '__label__nno_Latn', '__label__cym_Latn', '__label__kik_Latn', '__label__kmb_Latn', '__label__ory_Orya', '__label__bel_Cyrl', '__label__bho_Deva', '__label__apc_Arab', '__label__bak_Cyrl', '__label__jav_Latn', '__label__yue_Hani', '__label__pbt_Arab', '__label__khm_Khmr', '__label__npi_Deva', '__label__npi_Latn', '__label__gug_Latn', '__label__uig_Arab', '__label__fur_Latn', '__label__kbp_Latn', '__label__hne_Deva', '__label__kam_Latn', '__label__gla_Latn', '__label__kab_Latn', '__label__arz_Arab', '__label__kaz_Cyrl', '__label__mri_Latn', '__label__lim_Latn', '__label__srd_Latn', '__label__sun_Latn', '__label__plt_Latn', '__label__mni_Beng', '__label__isl_Latn', '__label__vec_Latn', '__label__glg_Latn', '__label__scn_Latn', '__label__fao_Latn', '__label__san_Deva', '__label__ltz_Latn', '__label__cjk_Latn', '__label__ast_Latn', '__label__lmo_Latn', '__label__szl_Latn', '__label__oci_Latn', '__label__fon_Latn', '__label__min_Latn', '__label__wol_Latn', '__label__lij_Latn', '__label__ajp_Arab', '__label__snd_Arab', '__label__dik_Latn', '__label__ary_Arab', '__label__lao_Laoo', '__label__ars_Arab', '__label__bjn_Latn', '__label__shn_Mymr', '__label__crh_Latn', '__label__aeb_Arab', '__label__ace_Latn', '__label__ckb_Arab', '__label__dyu_Latn', '__label__ltg_Latn', '__label__kmr_Latn', '__label__ban_Latn', '__label__mai_Deva', '__label__fuv_Latn', '__label__kac_Latn', '__label__taq_Latn', '__label__bam_Latn', '__label__sat_Olck', '__label__tzm_Tfng', '__label__bug_Latn', '__label__dzo_Tibt', '__label__kas_Deva', '__label__fas_Arab', '__label__nus_Latn', '__label__knc_Latn', '__label__mag_Deva', '__label__taq_Tfng', '__label__kas_Arab', '__label__knc_Arab', '__label__bjn_Arab', '__label__ace_Arab', '__label__kea_Latn', '__label__awa_Deva', '__label__acm_Arab', '__label__bod_Tibt', '__label__sot_Latn', '__label__ydd_Hebr', '__label__azb_Arab']

#custom model from limited languages
glot_model_lim = CustomLID(glot_model_path, languages = flores_glotlid, mode='before')

def glot_lid(text):
    labels, probs = glot_model_lim.predict(text, k=2)
    
    return {label for label,prob in zip(labels,probs) if prob>= 0.3}
    
def apply_glot_lid(df):
            
    df['Pred'] = df['Text'].apply(glot_lid)
        
    return df

# %%
# Apply model to all data
df_eval_g = apply_glot_lid(df_eval_g)  # results are stored in 'Predicted Labels'

# Normalize the ground truth label column to set
df_eval_g["True Labels"] = df_eval_g["True Labels"].apply(lambda x: set(x) if isinstance(x, list) or isinstance(x, set) else set(x.split()))

# %% [markdown]
# MONO-ENGLISH

# %%
subset_e_g  = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_e["True Labels"].values)]    # Mono English

em_e_g, pm_e_g = em_pm_mono(subset_e_g["True Labels"], subset_e_g["Pred"])

# Output hasil
print(f"#EM: {em_e_g}")
print(f"#PM: {pm_e_g}")
# Out:
# #EM: 460
# #PM: 463

# %% [markdown]
# TURKISH-ENGLISH EVAL

# %%
subset_te_g = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_te["True Labels"].values)]
subset_t_g  = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_t["True Labels"].values)]

# CS Turkish–English: EM / PM
em_te_g, pm_te_g = em_pm_cs(subset_te_g["True Labels"], subset_te_g["Pred"])

# FP Turkish–English
fp_te_g = count_fp(subset_te_g["True Labels"], subset_te_g["Pred"])

# Mono Turkish: EM / PM
em_t_g, pm_t_g = em_pm_mono(subset_t_g["True Labels"], subset_t_g["Pred"])

# Output hasil
print(f"#EM: {em_te_g}")
print(f"#PM: {pm_te_g}")
print(f"#FP: {fp_te_g}")
# Out:
# #EM: 4
# #PM: 330
# #FP: 3

# %% [markdown]
# BASQUE-SPANISH EVAL

# %%
subset_bs_g = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_bs["True Labels"].values)]
subset_b_g  = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_b["True Labels"].values)]
subset_s_g  = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_s["True Labels"].values)]

# CS Basque–Spanish: EM / PM
em_bs_g, pm_bs_g = em_pm_cs(subset_bs_g["True Labels"], subset_bs_g["Pred"])

#FP
fp_bs_g = count_fp(subset_bs_g["True Labels"], subset_bs_g["Pred"])

# Mono Basque: EM / PM
em_b_g, pm_b_g = em_pm_mono(subset_b_g["True Labels"], subset_b_g["Pred"])

# Mono Spanish: EM / PM
em_s_g, pm_s_g = em_pm_mono(subset_s_g["True Labels"], subset_s_g["Pred"])

# Output hasil
print(f"#EM: {em_bs_g}")
print(f"#PM: {pm_bs_g}")
print(f"#FP: {fp_bs_g}")
# Out:
# #EM: 9
# #PM: 430
# #FP: 1

# %% [markdown]
# HINDI_ENGLISH EVAL

# %%
subset_he_g = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_he["True Labels"].values)]
subset_h_g  = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_h["True Labels"].values)]
subset_e_g  = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_e["True Labels"].values)]

# EM / PM untuk CS Hindi–English
em_he_g, pm_he_g = em_pm_cs(subset_he_g["True Labels"], subset_he_g["Pred"])

# FP 
fp_he_g = count_fp(subset_he_g["True Labels"], subset_he_g["Pred"])

# Mono Hindi: EM / PM
em_h_g, pm_h_g = em_pm_mono(subset_h_g["True Labels"], subset_h_g["Pred"])

# Output hasil
print(f"#EM: {em_he_g}")
print(f"#PM: {pm_he_g}")
print(f"#FP: {fp_he_g}")
# Out:
# #EM: 0
# #PM: 84
# #FP: 4

# %% [markdown]
# NEPALI-ENGLISH EVAL

# %%
subset_ne_g = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_ne["True Labels"].values)]
subset_n_g  = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_n["True Labels"].values)]
subset_e_g  = df_eval_g[df_eval_g["True Labels"].apply(lambda x: x in df_e["True Labels"].values)]

# EM / PM untuk CS Nepali–English
em_ne_g, pm_ne_g = em_pm_cs(subset_ne_g["True Labels"], subset_ne_g["Pred"])

# FP 
fp_ne_g = count_fp(subset_ne_g["True Labels"], subset_ne_g["Pred"])
# Mono Nepali: EM / PM

em_n_g, pm_n_g = em_pm_mono(subset_n_g["True Labels"], subset_n_g["Pred"])

# Output hasil
print(f"#EM: {em_ne_g}")
print(f"#PM: {pm_ne_g}")
print(f"#FP: {fp_ne_g}")
# Out:
# #EM: 0
# #PM: 118
# #FP: 7

# %% [markdown]
# 3. OpenLID with MaskLID

# %%
# masklid is the name of masklid.py
from masklid import MaskLID


om_model = MaskLID(glot_model_path, languages = -1)

def om_lid(text):
    prediction = om_model.predict_codeswitch(text, beta = 15 , alpha = 3, max_lambda = 2, min_length = 20, min_prob = 0.90, max_retry=3, alpha_step_increase = 3, beta_step_increase = 5)
    
    return set(prediction.keys())
    
def apply_om_lid(df):
    df['Pred'] = df['Text'].apply(om_lid)
        
    return df
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Apply model to all data
df_eval_om = apply_om_lid(df_eval_om)  # results are stored in 'Predicted Labels'

# Normalize the ground truth label column to set
df_eval_om["True Labels"] = df_eval_om["True Labels"].apply(lambda x: set(x) if isinstance(x, list) or isinstance(x, set) else set(x.split()))
# Out:
# text= yarın bir status yapıp işlerin üstünden geçelim label= __label__tur_Latn (new text), dict data= yarın status üstünden geçelim dict_mask= yarın bir yapıp işlerin üstünden geçelim 0 0
# text= yarın status üstünden geçelim label= __label__tur_Latn (new text), dict data= yarın status üstünden geçelim dict_mask= yarın üstünden geçelim 1 0
# text= ben dataları sort ettim peki nedir bu işin process'i schedule ettik biz sizi briefing room'da bekliyor olacağım onu yapıyor olman lazım zaten label= __label__tur_Latn (new text), dict data= ben dataları sort peki bu process'i schedule biz sizi briefing room'da onu olman lazım zaten dict_mask= dataları ettim nedir işin ettik room'da bekliyor olacağım yapıyor olman lazım zaten 0 0
# text= ben dataları sort peki bu process'i schedule biz sizi briefing room'da onu olman lazım zaten label= __label__tur_Latn (new text), dict data= ben dataları sort peki bu process'i schedule biz sizi briefing room'da onu olman lazım zaten dict_mask= dataları room'da olman lazım zaten 1 0
# text= ben rain'ince umbrella alıp altında hide yapcam label= __label__tur_Latn (new text), dict data= ben rain'ince umbrella alıp hide yapcam dict_mask= alıp altında 0 0
# text= ben rain'ince umbrella alıp hide yapcam label= __label__tur_Latn (new text), dict data= ben rain'ince umbrella alıp hide yapcam dict_mask= alıp 1 0
# text= ben rain'ince umbrella alıp hide yapcam label= __label__tur_Latn (new text), dict data= ben rain'ince umbrella alıp hide yapcam dict_mask= alıp 1 1
# text= ben rain'ince umbrella alıp hide yapcam label= __label__tur_Latn (new text), dict data= ben rain'ince umbrella alıp hide yapcam dict_mask= alıp 1 2
# text= progress yavaş ilerliyor birbirinizi boost edin label= __label__tur_Latn (new text), dict data= progress boost edin dict_mask= yavaş ilerliyor birbirinizi 0 0
# text= şu malları bulk halinde göndermemiz lazım label= __label__tur_Latn (new text), dict data= malları bulk halinde lazım dict_mask= şu malları bulk göndermemiz lazım 0 0
# text= malları bulk halinde lazım label= __label__tur_Latn (new text), dict data= malları bulk halinde lazım dict_mask= malları bulk lazım 1 0
# text= malları bulk halinde lazım label= __label__tur_Latn (new text), dict data= malları bulk halinde lazım dict_mask= malları bulk lazım 1 1
# text= malları bulk halinde lazım label= __label__tur_Latn (new text), dict data= bulk halinde lazım dict_mask= malları bulk lazım 1 2
# text= bugün toplantıda on site olamayacağım label= __label__tur_Latn (new text), dict data= on site dict_mask= bugün toplantıda olamayacağım 0 0
# text= dip not koyuyor bi de kademsizler lafın arasına but it's optional diye label= __label__tur_Latn (new text), dict data= dip not bi de kademsizler lafın arasına but it's optional diye dict_mask= koyuyor kademsizler lafın arasına 0 0
# text= dip not bi de kademsizler lafın arasına but it's optional diye label= __label__tur_Latn (new text), dict data= dip not bi de kademsizler lafın arasına but it's optional diye dict_mask= kademsizler lafın arasına 1 0
# text= dip not bi de kademsizler lafın arasına but it's optional diye label= __label__tur_Latn (new text), dict data= dip not bi de lafın but it's optional diye dict_mask= kademsizler lafın arasına 1 1
# text= dip not bi de kademsizler lafın arasına but it's optional diye label= __label__tur_Latn (new text), dict data= dip not bi de lafın but it's optional diye dict_mask= lafın 1 2
# text= gerçekten neyi ispatlamak istediklerini anlamıyorum kendilerini ortama mı adjust ediyorlar n'apıyorlarsa artık label= __label__tur_Latn (new text), dict data= neyi ispatlamak ortama adjust dict_mask= gerçekten istediklerini anlamıyorum kendilerini mı ediyorlar n'apıyorlarsa artık 0 0
# text= neyi ispatlamak ortama adjust label= __label__tur_Latn (new text), dict data= neyi ispatlamak ortama adjust dict_mask=  1 0
# text= neyi ispatlamak ortama adjust label= __label__tur_Latn (new text), dict data= neyi ispatlamak ortama adjust dict_mask=  1 1
# text= neyi ispatlamak ortama adjust label= __label__tur_Latn (new text), dict data= neyi ispatlamak ortama adjust dict_mask= neyi 1 2
# text= ama çoğu kelime ciddi manada gereksiz kullanılıyor ve çok eğreti duruyor product'a ürün demek change etmek'e değiştirme demek ya da reach'e ulaşma demek çok zor değildir label= __label__tur_Latn (new text), dict data= ama kelime ciddi manada ve product'a ürün demek change demek ya da reach'e demek zor dict_mask= çoğu gereksiz kullanılıyor ve çok eğreti duruyor ürün demek etmek'e değiştirme demek ulaşma demek çok değildir 0 0
# text= ama kelime ciddi manada ve product'a ürün demek change demek ya da reach'e demek zor label= __label__tur_Latn (new text), dict data= ama kelime ciddi manada ve product'a ürün demek change demek ya da reach'e demek zor dict_mask= ve ürün demek demek demek 1 0
# text= arkadaslar herkes line-up'larini finalize etsin ve forecastleri girmeye baslasin label= __label__tur_Latn (new text), dict data= arkadaslar herkes line-up'larini finalize etsin ve girmeye baslasin dict_mask= arkadaslar herkes ve forecastleri 0 0
# text= arkadaslar herkes line-up'larini finalize etsin ve girmeye baslasin label= __label__tur_Latn (new text), dict data= arkadaslar herkes line-up'larini finalize etsin ve girmeye baslasin dict_mask= arkadaslar herkes ve 1 0
# text= arkadaslar herkes line-up'larini finalize etsin ve girmeye baslasin label= __label__tur_Latn (new text), dict data= arkadaslar herkes line-up'larini finalize etsin girmeye baslasin dict_mask= arkadaslar herkes ve girmeye 1 1
# text= yöneticiyi koridorda sıkıştırıp bilmemne bey şunlar şöyle şöyle bunlar da böyle böyle e nolucak sen söyle demem sonucu work around yap dediydi o ne ola ki de denmiyo tabi label= __label__tur_Latn (new text), dict data= koridorda bilmemne bey da e nolucak sen demem sonucu work around yap o ne ola ki de denmiyo tabi dict_mask= yöneticiyi sıkıştırıp şunlar şöyle şöyle bunlar böyle böyle söyle sonucu dediydi 0 0
# text= koridorda bilmemne bey da e nolucak sen demem sonucu work around yap o ne ola ki de denmiyo tabi label= __label__tur_Latn (new text), dict data= koridorda bilmemne bey da e nolucak sen demem sonucu work around yap o ne ola ki de denmiyo tabi dict_mask= sonucu 1 0
# text= koridorda bilmemne bey da e nolucak sen demem sonucu work around yap o ne ola ki de denmiyo tabi label= __label__tur_Latn (new text), dict data= koridorda bilmemne bey da e nolucak sen demem work around yap o ne ola ki de denmiyo tabi dict_mask= bilmemne sonucu 1 1
# text= koridorda bilmemne bey da e nolucak sen demem sonucu work around yap o ne ola ki de denmiyo tabi label= __label__tur_Latn (new text), dict data= koridorda bilmemne bey da e nolucak sen demem work around yap o ne ola ki de denmiyo tabi dict_mask= bilmemne 1 2
# text= böyle bir cancellation fee ile kendimizi hedge etmek zorundayız açıkçası aksi halde oraya alloke ettiğimiz resource un emek ve zamanını finance edememiş oluruz label= __label__tur_Latn (new text), dict data= cancellation fee ile hedge aksi halde oraya alloke resource un emek ve finance dict_mask= böyle bir ile kendimizi etmek zorundayız açıkçası ettiğimiz ve zamanını edememiş oluruz 0 0
# text= cancellation fee ile hedge aksi halde oraya alloke resource un emek ve finance label= __label__tur_Latn (new text), dict data= cancellation fee ile hedge aksi halde oraya alloke resource un emek ve finance dict_mask= ile ve 1 0
# text= cancellation fee ile hedge aksi halde oraya alloke resource un emek ve finance label= __label__tur_Latn (new text), dict data= cancellation fee ile hedge aksi halde oraya alloke resource un emek finance dict_mask= ile ve 1 1
# text= cancellation fee ile hedge aksi halde oraya alloke resource un emek ve finance label= __label__tur_Latn (new text), dict data= cancellation fee hedge aksi halde oraya alloke resource un emek finance dict_mask= ile 1 2
# text= time frame ve position bildirmeden system out yapmıyoruz label= __label__tur_Latn (new text), dict data= time frame ve position system out dict_mask= ve bildirmeden yapmıyoruz 0 0
# text= time frame ve position system out label= __label__jam_Latn (new text), dict data= time ve position out dict_mask= time frame position system out 1 0
# text= time frame ve position system out label= __label__jam_Latn (new text), dict data= time ve dict_mask= time position out 1 1
# text= time frame ve position system out label= __label__jam_Latn (new text), dict data= time ve dict_mask= time 1 2
# text= job sistemde schedule edilerek belli bir saatte execute edilecektir label= __label__tur_Latn (new text), dict data= job sistemde schedule belli saatte execute dict_mask= sistemde edilerek bir edilecektir 0 0
# text= job sistemde schedule belli saatte execute label= __label__fin_Latn (new text), dict data= job sistemde schedule belli saatte execute dict_mask= saatte 1 0
# text= job sistemde schedule belli saatte execute label= __label__fin_Latn (new text), dict data= job sistemde schedule belli saatte execute dict_mask= saatte 1 1
# text= job sistemde schedule belli saatte execute label= __label__fin_Latn (new text), dict data= job sistemde schedule belli saatte execute dict_mask= schedule saatte 1 2
# text= birgün gazetesinin de handle ettiği olmamışlık label= __label__tur_Latn (new text), dict data= birgün de handle dict_mask= birgün gazetesinin ettiği olmamışlık 0 0
# text= emin değilim kuvvetle muhtemel bir plaza çalışanı eğlenmeye geldiği barda arkadaşlarına şimdi biraz önce şöyle seslendi evet ne içiyorsunuz bu round benden label= __label__tur_Latn (new text), dict data= emin kuvvetle plaza barda şimdi evet ne bu round benden dict_mask= değilim kuvvetle muhtemel bir çalışanı eğlenmeye geldiği arkadaşlarına şimdi biraz önce şöyle seslendi evet içiyorsunuz 0 0
# text= emin kuvvetle plaza barda şimdi evet ne bu round benden label= __label__tur_Latn (new text), dict data= emin kuvvetle plaza barda şimdi evet ne bu round benden dict_mask= kuvvetle şimdi evet 1 0
# text= emin kuvvetle plaza barda şimdi evet ne bu round benden label= __label__tur_Latn (new text), dict data= emin kuvvetle plaza barda şimdi evet ne bu round benden dict_mask= kuvvetle barda şimdi evet benden 1 1
# text= sana thankslerimi yolluyorum bu dile aittir label= __label__tur_Latn (new text), dict data= sana thankslerimi bu dile aittir dict_mask= yolluyorum aittir 0 0
# text= sana thankslerimi bu dile aittir label= __label__tur_Latn (new text), dict data= sana thankslerimi bu dile aittir dict_mask= aittir 1 0
# text= sana thankslerimi bu dile aittir label= __label__tur_Latn (new text), dict data= sana thankslerimi bu dile aittir dict_mask= aittir 1 1
# text= sana thankslerimi bu dile aittir label= __label__tur_Latn (new text), dict data= sana thankslerimi bu dile dict_mask= thankslerimi aittir 1 2
# text= kırmızı ile işaretlediklerim dışındakiler pass edilebilecek gibi duruyor sen client'ı push et o arada sonra bana feedback verirsin sen silent kal ben konuşucam şimdi label= __label__tur_Latn (new text), dict data= ile pass edilebilecek sen push et o arada bana feedback sen silent kal ben şimdi dict_mask= kırmızı ile işaretlediklerim dışındakiler edilebilecek gibi duruyor client'ı sonra verirsin konuşucam şimdi 0 0
# text= ile pass edilebilecek sen push et o arada bana feedback sen silent kal ben şimdi label= __label__tur_Latn (new text), dict data= ile pass edilebilecek sen push et o arada bana feedback sen silent kal ben şimdi dict_mask= ile edilebilecek şimdi 1 0
# text= evet evet gelmeyecekmiş no dedi diğerleri accept ederse invitation'ı reply et label= __label__tur_Latn (new text), dict data= evet evet no dedi accept ederse reply et dict_mask= evet evet gelmeyecekmiş dedi diğerleri ederse invitation'ı 0 0
# text= evet evet no dedi accept ederse reply et label= __label__tur_Latn (new text), dict data= evet evet no dedi accept ederse reply et dict_mask= evet evet dedi ederse 1 0
# text= bilmem ne parçalarını ship ettik bu işi senin drive etmeni istiyorum nakliyeci ile konuşup parçanın pick-up'ını ayarlar mısın label= __label__tur_Latn (new text), dict data= bilmem ne ship bu işi drive nakliyeci ile ayarlar mısın dict_mask= bilmem parçalarını ettik işi senin etmeni istiyorum ile konuşup parçanın pick-up'ını mısın 0 0
# text= bilmem ne ship bu işi drive nakliyeci ile ayarlar mısın label= __label__tur_Latn (new text), dict data= bilmem ne ship bu işi drive nakliyeci ile ayarlar mısın dict_mask= bilmem işi ile mısın 1 0
# text= ikinci quarter’da karlılığımız yüzde oranında artmış durumda label= __label__tur_Latn (new text), dict data= ikinci quarter’da artmış dict_mask= ikinci karlılığımız yüzde oranında artmış durumda 0 0
# text= ikinci quarter’da artmış label= __label__azj_Latn (new text), dict data=  dict_mask= ikinci quarter’da artmış 1 0
# text= bir de cümlelik bir konuşmanın cümlesinin tamamen ingilizce olmasına karşıyım you know what seni döverim çocuk label= __label__tur_Latn (new text), dict data= de cümlelik tamamen ingilizce you know what seni döverim dict_mask= bir bir konuşmanın cümlesinin olmasına karşıyım çocuk 0 0
# text= de cümlelik tamamen ingilizce you know what seni döverim label= __label__tur_Latn (new text), dict data= de cümlelik tamamen ingilizce you know what seni döverim dict_mask=  1 0
# text= de cümlelik tamamen ingilizce you know what seni döverim label= __label__tur_Latn (new text), dict data= de cümlelik tamamen ingilizce you know what seni döverim dict_mask=  1 1
# text= de cümlelik tamamen ingilizce you know what seni döverim label= __label__tur_Latn (new text), dict data= de cümlelik tamamen ingilizce you know what seni döverim dict_mask= tamamen 1 2
# text= şuanda yeni yeni league of legends yayınları yapmaya başladım ve streamer olarak kendimi geliştirmeyi düşünüyorum label= __label__tur_Latn (new text), dict data= yeni yeni league of legends ve streamer kendimi dict_mask= şuanda yayınları yapmaya başladım ve olarak kendimi geliştirmeyi düşünüyorum 0 0
# text= yeni yeni league of legends ve streamer kendimi label= __label__tur_Latn (new text), dict data= yeni yeni league of legends ve streamer kendimi dict_mask= ve kendimi 1 0
# text= yeni yeni league of legends ve streamer kendimi label= __label__tur_Latn (new text), dict data= yeni yeni league of legends streamer kendimi dict_mask= ve kendimi 1 1
# text= yeni yeni league of legends ve streamer kendimi label= __label__tur_Latn (new text), dict data= yeni yeni league of legends streamer kendimi dict_mask= kendimi 1 2
# text= pek try hard oyunları değilde genelde fun gameleri tercih ediyorum ve seviyeli oyuncularla oynamayı seviyorum label= __label__tur_Latn (new text), dict data= pek try hard genelde fun gameleri tercih ve dict_mask= oyunları değilde genelde ediyorum ve seviyeli oyuncularla oynamayı seviyorum 0 0
# text= pek try hard genelde fun gameleri tercih ve label= __label__tur_Latn (new text), dict data= pek try hard genelde fun gameleri tercih ve dict_mask= genelde ve 1 0
# text= pek try hard genelde fun gameleri tercih ve label= __label__tur_Latn (new text), dict data= pek try hard fun gameleri tercih dict_mask= genelde gameleri tercih ve 1 1
# text= istediğiniz şarkı streamde dinlenmesini istiyorsanız yada istekleriniz için yayın chat'inden yada facebook sayfamdan mesaj atarak ulaşabilirsiniz label= __label__tur_Latn (new text), dict data= streamde yada chat'inden yada facebook mesaj atarak dict_mask= istediğiniz şarkı dinlenmesini istiyorsanız istekleriniz için yayın sayfamdan ulaşabilirsiniz 0 0
# text= streamde yada chat'inden yada facebook mesaj atarak label= __label__tur_Latn (new text), dict data= streamde yada chat'inden yada facebook mesaj atarak dict_mask=  1 0
# text= streamde yada chat'inden yada facebook mesaj atarak label= __label__tur_Latn (new text), dict data= streamde yada chat'inden yada facebook mesaj atarak dict_mask= facebook 1 1
# text= streamde yada chat'inden yada facebook mesaj atarak label= __label__tur_Latn (new text), dict data= streamde yada chat'inden yada facebook mesaj atarak dict_mask= facebook 1 2
# text= berkecim dün maile blueprint'leri attach etmemişsin dalgınlığına geldi sanırım label= __label__tur_Latn (new text), dict data= berkecim dün maile blueprint'leri attach dict_mask= dün etmemişsin dalgınlığına geldi sanırım 0 0
# text= berkecim dün maile blueprint'leri attach label= __label__tur_Latn (new text), dict data= berkecim dün maile blueprint'leri attach dict_mask= dün 1 0
# text= berkecim dün maile blueprint'leri attach label= __label__tur_Latn (new text), dict data= berkecim maile blueprint'leri attach dict_mask= dün 1 1
# text= berkecim dün maile blueprint'leri attach label= __label__tur_Latn (new text), dict data= berkecim maile blueprint'leri attach dict_mask=  1 2
# text= çok sorry efendim hemen check edip yolluyorum label= __label__tur_Latn (new text), dict data= sorry efendim hemen check edip dict_mask= çok efendim yolluyorum 0 0
# text= sorry efendim hemen check edip label= __label__tur_Latn (new text), dict data= sorry efendim hemen check edip dict_mask= efendim 1 0
# text= sorry efendim hemen check edip label= __label__tur_Latn (new text), dict data= sorry efendim hemen check edip dict_mask= efendim edip 1 1
# text= sorry efendim hemen check edip label= __label__tur_Latn (new text), dict data= sorry hemen check edip dict_mask= efendim edip 1 2
# text= projedeki defect'lerin üzerinden birlikte geçelim label= __label__tur_Latn (new text), dict data= defect'lerin geçelim dict_mask= projedeki defect'lerin üzerinden birlikte geçelim 0 0
# text= defect'lerin geçelim label= __label__tur_Latn (new text), dict data= defect'lerin geçelim dict_mask= defect'lerin geçelim 1 0
# text= neyse canım lütfen beni bu tip maillerde ekleyip forward etmeyin diğerleri ok dir label= __label__tur_Latn (new text), dict data= neyse canım bu tip maillerde ekleyip forward ok dir dict_mask= canım lütfen beni ekleyip etmeyin diğerleri 0 0
# text= neyse canım bu tip maillerde ekleyip forward ok dir label= __label__tur_Latn (new text), dict data= neyse canım bu tip maillerde ekleyip forward ok dir dict_mask= canım ekleyip 1 0
# text= neyse canım bu tip maillerde ekleyip forward ok dir label= __label__tur_Latn (new text), dict data= neyse bu tip maillerde ekleyip forward ok dir dict_mask= canım ekleyip 1 1
# text= neyse canım bu tip maillerde ekleyip forward ok dir label= __label__tur_Latn (new text), dict data= neyse bu tip maillerde forward ok dir dict_mask= ekleyip 1 2
# text= whiteraistlin bey comment'leriniz için müteşekkiriz şimdi biz comment'lerimizi client'ımıza forward edeceğiz onlardan approval'ı almamızı müteakip hızlı bir kick-off meeting için bir date set ederiz bizimkilerin de participate etmek istemeleri halinde sizin client'ınız da iştirak ederse seviniriz label= __label__tur_Latn (new text), dict data= whiteraistlin bey müteşekkiriz şimdi biz comment'lerimizi forward müteakip kick-off meeting date set de participate halinde sizin da iştirak ederse seviniriz dict_mask= comment'leriniz için müteşekkiriz şimdi comment'lerimizi client'ımıza edeceğiz onlardan approval'ı almamızı müteakip hızlı bir için bir ederiz bizimkilerin etmek istemeleri client'ınız iştirak ederse seviniriz 0 0
# text= whiteraistlin bey müteşekkiriz şimdi biz comment'lerimizi forward müteakip kick-off meeting date set de participate halinde sizin da iştirak ederse seviniriz label= __label__tur_Latn (new text), dict data= whiteraistlin bey müteşekkiriz şimdi biz comment'lerimizi forward müteakip kick-off meeting date set de participate halinde sizin da iştirak ederse seviniriz dict_mask= müteşekkiriz şimdi comment'lerimizi müteakip iştirak ederse seviniriz 1 0
# text= take cover grenade ya da fire in the hole diye karşılık vereceksin böylesine mavi ekran versin direk pardon blue screen of death diyecektim label= __label__tur_Latn (new text), dict data= take cover grenade ya da fire in the hole diye mavi ekran direk pardon blue screen of death dict_mask= karşılık vereceksin böylesine versin diyecektim 0 0
# text= take cover grenade ya da fire in the hole diye mavi ekran direk pardon blue screen of death label= __label__eng_Latn (new text), dict data= take cover grenade ya da fire in the hole diye mavi ekran direk pardon blue screen of death dict_mask= cover blue 1 0
# text= take cover grenade ya da fire in the hole diye mavi ekran direk pardon blue screen of death label= __label__eng_Latn (new text), dict data= take cover grenade ya da fire in the hole diye mavi ekran direk pardon blue screen of death dict_mask= cover grenade blue death 1 1
# text= değerde dolar tutarı için hedge edilmekte ve yıllık olarak proje süresi arttıkça roll out edilmekte ve transaction masrafı oluşmaktadır label= __label__tur_Latn (new text), dict data= dolar hedge ve proje roll out ve transaction dict_mask= değerde tutarı için edilmekte ve yıllık olarak süresi arttıkça edilmekte ve masrafı oluşmaktadır 0 0
# text= dolar hedge ve proje roll out ve transaction label= __label__tur_Latn (new text), dict data= dolar hedge ve proje roll out ve transaction dict_mask= ve ve 1 0
# text= dolar hedge ve proje roll out ve transaction label= __label__tur_Latn (new text), dict data= dolar hedge proje roll out transaction dict_mask= dolar ve ve 1 1
# text= dolar hedge ve proje roll out ve transaction label= __label__tur_Latn (new text), dict data= dolar hedge proje roll out transaction dict_mask= dolar 1 2
# text= bizim plaza asansöründe duyduğum bir laf buna örnek verilebilir dışarıda olunca focus'um dilute oluyor label= __label__tur_Latn (new text), dict data= bizim plaza asansöründe laf buna focus'um dilute dict_mask= asansöründe duyduğum bir örnek verilebilir dışarıda olunca oluyor 0 0
# text= bizim plaza asansöründe laf buna focus'um dilute label= __label__tur_Latn (new text), dict data= bizim plaza asansöründe laf buna focus'um dilute dict_mask= asansöründe 1 0
# text= bizim plaza asansöründe laf buna focus'um dilute label= __label__tur_Latn (new text), dict data= bizim plaza asansöründe laf buna focus'um dilute dict_mask= asansöründe 1 1
# text= bizim plaza asansöründe laf buna focus'um dilute label= __label__tur_Latn (new text), dict data= bizim plaza laf buna focus'um dilute dict_mask= asansöründe focus'um 1 2
# text= salary olarak daha tatmin edici bir yer buldum label= __label__tur_Latn (new text), dict data= salary daha tatmin edici yer buldum dict_mask= olarak bir yer 0 0
# text= salary daha tatmin edici yer buldum label= __label__tur_Latn (new text), dict data= salary daha tatmin edici yer buldum dict_mask= yer 1 0
# text= salary daha tatmin edici yer buldum label= __label__tur_Latn (new text), dict data= salary daha tatmin edici yer buldum dict_mask= daha yer 1 1
# text= salary daha tatmin edici yer buldum label= __label__tur_Latn (new text), dict data= salary daha tatmin edici yer buldum dict_mask= daha yer 1 2
# text= definately bir weekend away yapılmalı buraya label= __label__tur_Latn (new text), dict data= definately weekend away buraya dict_mask= bir yapılmalı buraya 0 0
# text= definately weekend away buraya label= __label__eng_Latn (new text), dict data= weekend away buraya dict_mask= definately 1 0
# text= definately weekend away buraya label= __label__eng_Latn (new text), dict data= weekend away buraya dict_mask=  1 1
# text= definately weekend away buraya label= __label__eng_Latn (new text), dict data= weekend away buraya dict_mask= weekend 1 2
# text= tamam ozakman'cığım ama bunu further discuss ediyor olacağız label= __label__tur_Latn (new text), dict data= tamam ama bunu further discuss dict_mask= ozakman'cığım ediyor olacağız 0 0
# text= tamam ama bunu further discuss label= __label__tur_Latn (new text), dict data= tamam ama bunu further discuss dict_mask=  1 0
# text= tamam ama bunu further discuss label= __label__tur_Latn (new text), dict data= tamam ama bunu further discuss dict_mask=  1 1
# text= tamam ama bunu further discuss label= __label__tur_Latn (new text), dict data= tamam ama bunu further discuss dict_mask=  1 2
# text= ilgili yatırımın business case'i hazırlanmalıdır label= __label__tur_Latn (new text), dict data= business case'i dict_mask= ilgili yatırımın hazırlanmalıdır 0 0
# text= sürece ilişkin best practice'ler ve şirket ihtiyaçları doğrultusunda belirlenmiştir label= __label__tur_Latn (new text), dict data= ilişkin best practice'ler ve dict_mask= sürece ilişkin ve şirket ihtiyaçları doğrultusunda belirlenmiştir 0 0
# text= ilişkin best practice'ler ve label= __label__tur_Latn (new text), dict data= ilişkin best practice'ler ve dict_mask= ilişkin ve 1 0
# text= ilişkin best practice'ler ve label= __label__tur_Latn (new text), dict data= best practice'ler dict_mask= ilişkin ve 1 1
# text= ilişkin best practice'ler ve label= __label__tur_Latn (new text), dict data= best practice'ler dict_mask=  1 2
# text= -belirlenen yol haritasındaki initiative'lerin uygulanması durumunda hedeflenen faydalar listelenmiştir label= __label__tur_Latn (new text), dict data= -belirlenen yol initiative'lerin hedeflenen faydalar dict_mask= -belirlenen haritasındaki uygulanması durumunda listelenmiştir 0 0
# text= -belirlenen yol initiative'lerin hedeflenen faydalar label= __label__tur_Latn (new text), dict data= -belirlenen yol initiative'lerin hedeflenen faydalar dict_mask= -belirlenen 1 0
# text= -belirlenen yol initiative'lerin hedeflenen faydalar label= __label__tur_Latn (new text), dict data= -belirlenen yol initiative'lerin hedeflenen faydalar dict_mask= -belirlenen 1 1
# text= -belirlenen yol initiative'lerin hedeflenen faydalar label= __label__tur_Latn (new text), dict data= yol initiative'lerin hedeflenen faydalar dict_mask= -belirlenen hedeflenen 1 2
# text= ama ben bunu şirketime expense edeceğim şeklinde bir cümle kalıbını az önce duyduğum edebiyat label= __label__tur_Latn (new text), dict data= ama ben bunu expense cümle az edebiyat dict_mask= şirketime edeceğim şeklinde bir kalıbını önce duyduğum edebiyat 0 0
# text= ama ben bunu expense cümle az edebiyat label= __label__tur_Latn (new text), dict data= ama ben bunu expense cümle az edebiyat dict_mask= edebiyat 1 0
# text= ama ben bunu expense cümle az edebiyat label= __label__tur_Latn (new text), dict data= ama ben bunu expense cümle az edebiyat dict_mask= edebiyat 1 1
# text= ama ben bunu expense cümle az edebiyat label= __label__tur_Latn (new text), dict data= ama ben bunu expense cümle az dict_mask= edebiyat 1 2
# text= first major bir durum olmadıkça standart sözleşme uygulanmaktadır label= __label__tur_Latn (new text), dict data= first major durum standart sözleşme dict_mask= bir olmadıkça sözleşme uygulanmaktadır 0 0
# text= first major durum standart sözleşme label= __label__tur_Latn (new text), dict data= first major durum standart sözleşme dict_mask= sözleşme 1 0
# text= first major durum standart sözleşme label= __label__tur_Latn (new text), dict data= first major durum standart dict_mask= sözleşme 1 1
# text= first major durum standart sözleşme label= __label__tur_Latn (new text), dict data= first major durum standart dict_mask= durum 1 2
# text= demonstrationını fiziksel olarak kullanıp olumlu sonuç alırsak spesifik olarak hayata geçiririz label= __label__tur_Latn (new text), dict data= demonstrationını fiziksel spesifik hayata geçiririz dict_mask= demonstrationını fiziksel olarak kullanıp olumlu sonuç alırsak olarak geçiririz 0 0
# text= demonstrationını fiziksel spesifik hayata geçiririz label= __label__tur_Latn (new text), dict data= demonstrationını fiziksel spesifik hayata geçiririz dict_mask= demonstrationını fiziksel geçiririz 1 0
# text= demonstrationını fiziksel spesifik hayata geçiririz label= __label__tur_Latn (new text), dict data= spesifik hayata dict_mask= demonstrationını fiziksel geçiririz 1 1
# text= demonstrationını fiziksel spesifik hayata geçiririz label= __label__tur_Latn (new text), dict data= spesifik hayata dict_mask=  1 2
# text= arkadaşlar meeting schedule edeceğiz bugün break sırasında saati precise edelim label= __label__tur_Latn (new text), dict data= meeting schedule break saati precise edelim dict_mask= arkadaşlar edeceğiz bugün sırasında 0 0
# text= meeting schedule break saati precise edelim label= __label__tur_Latn (new text), dict data= meeting schedule break saati precise edelim dict_mask=  1 0
# text= meeting schedule break saati precise edelim label= __label__tur_Latn (new text), dict data= meeting schedule break saati precise edelim dict_mask=  1 1
# text= meeting schedule break saati precise edelim label= __label__tur_Latn (new text), dict data= meeting schedule break saati precise edelim dict_mask= edelim 1 2
# text= arkadaşlar workflow'umuzu bu mindset'te build etmeyelim label= __label__tur_Latn (new text), dict data= workflow'umuzu bu mindset'te build dict_mask= arkadaşlar etmeyelim 0 0
# text= workflow'umuzu bu mindset'te build label= __label__tur_Latn (new text), dict data= workflow'umuzu bu mindset'te build dict_mask=  1 0
# text= workflow'umuzu bu mindset'te build label= __label__tur_Latn (new text), dict data= workflow'umuzu bu mindset'te build dict_mask=  1 1
# text= workflow'umuzu bu mindset'te build label= __label__tur_Latn (new text), dict data= workflow'umuzu bu mindset'te build dict_mask= mindset'te 1 2
# text= günlerden bir gün yine bizim sekreterin kafasını yerken yıllarca plaza edebiyatıyla yoğrulmuş olan executive ablamızın biraz da etraftaki tercümanlara hava atma kaygısıyla ağzından şu sözler dökülüverdi label= __label__tur_Latn (new text), dict data= gün yine bizim sekreterin plaza executive ablamızın da etraftaki hava atma sözler dict_mask= günlerden bir gün sekreterin kafasını yerken yıllarca edebiyatıyla yoğrulmuş olan ablamızın biraz tercümanlara kaygısıyla ağzından şu sözler dökülüverdi 0 0
# text= gün yine bizim sekreterin plaza executive ablamızın da etraftaki hava atma sözler label= __label__tur_Latn (new text), dict data= gün yine bizim sekreterin plaza executive ablamızın da etraftaki hava atma sözler dict_mask= gün sekreterin ablamızın sözler 1 0
# text= meeting yapiyoruz sonra alınan kararları check edip briefleri mail ile push edeceğiz işleri outsource etmek gerekebilir plazadili label= __label__tur_Latn (new text), dict data= meeting alınan check edip briefleri mail ile push outsource plazadili dict_mask= yapiyoruz sonra alınan kararları ile edeceğiz işleri etmek gerekebilir plazadili 0 0
# text= meeting alınan check edip briefleri mail ile push outsource plazadili label= __label__tur_Latn (new text), dict data= meeting alınan check edip briefleri mail ile push outsource plazadili dict_mask= alınan ile plazadili 1 0
# text= oblivion ve masquerade nedense çok hoşuma gitmiştir her zaman için label= __label__tur_Latn (new text), dict data= oblivion ve masquerade nedense hoşuma her zaman dict_mask= ve çok hoşuma gitmiştir zaman için 0 0
# text= oblivion ve masquerade nedense hoşuma her zaman label= __label__tur_Latn (new text), dict data= oblivion ve masquerade nedense hoşuma her zaman dict_mask= ve hoşuma zaman 1 0
# text= oblivion ve masquerade nedense hoşuma her zaman label= __label__tur_Latn (new text), dict data= oblivion masquerade nedense her zaman dict_mask= ve hoşuma zaman 1 1
# text= oblivion ve masquerade nedense hoşuma her zaman label= __label__tur_Latn (new text), dict data= oblivion masquerade nedense her zaman dict_mask= zaman 1 2
# text= ingiltere capinda the independent tarafindan yapilan ankette mother sozcugu birinci secilmitir label= __label__tur_Latn (new text), dict data= ingiltere capinda the independent tarafindan yapilan ankette mother sozcugu birinci secilmitir dict_mask= tarafindan birinci secilmitir 0 0
# text= ingiltere capinda the independent tarafindan yapilan ankette mother sozcugu birinci secilmitir label= __label__tur_Latn (new text), dict data= ingiltere capinda the independent tarafindan yapilan ankette mother sozcugu birinci secilmitir dict_mask= tarafindan birinci secilmitir 1 0
# text= ingiltere capinda the independent tarafindan yapilan ankette mother sozcugu birinci secilmitir label= __label__tur_Latn (new text), dict data= ingiltere capinda the independent yapilan ankette mother sozcugu secilmitir dict_mask= tarafindan birinci secilmitir 1 1
# text= ingiltere capinda the independent tarafindan yapilan ankette mother sozcugu birinci secilmitir label= __label__tur_Latn (new text), dict data= ingiltere capinda the independent yapilan ankette mother sozcugu dict_mask= secilmitir 1 2
# text= love olmutur destiny ve tranquillity de listede hepsini hatirlamiyorum bulursam editte gelecek label= __label__tur_Latn (new text), dict data= love olmutur destiny ve tranquillity de listede hepsini bulursam editte dict_mask= olmutur ve hepsini hatirlamiyorum bulursam gelecek 0 0
# text= love olmutur destiny ve tranquillity de listede hepsini bulursam editte label= __label__tur_Latn (new text), dict data= love olmutur destiny ve tranquillity de listede hepsini bulursam editte dict_mask= olmutur ve hepsini bulursam 1 0
# text= british councilin kurulus yildonumu sebebiyle duzenlenen ingilizce konusulmayan ulkede bin kisinin katildigi bir arastirma sonucunda ingilizcedeki en guzel kelimenin mother oldugu gorulmus label= __label__tur_Latn (new text), dict data= british councilin kurulus yildonumu duzenlenen ingilizce ulkede bin kisinin katildigi arastirma ingilizcedeki en guzel mother oldugu gorulmus dict_mask= sebebiyle konusulmayan katildigi bir sonucunda ingilizcedeki kelimenin 0 0
# text= british councilin kurulus yildonumu duzenlenen ingilizce ulkede bin kisinin katildigi arastirma ingilizcedeki en guzel mother oldugu gorulmus label= __label__tur_Latn (new text), dict data= british councilin kurulus yildonumu duzenlenen ingilizce ulkede bin kisinin katildigi arastirma ingilizcedeki en guzel mother oldugu gorulmus dict_mask= katildigi ingilizcedeki 1 0
# text= neyse tabii ki en guzel kelime mother father brother-in-law filan degil basbayagi diarrheadir gerek okunusundaki karizma gerekse tasidigi anlam itibariyle bu kelimeyi her sarfettiginizde goreceginiz saygi artacaktir label= __label__tur_Latn (new text), dict data= neyse tabii ki en guzel kelime mother father brother-in-law filan degil basbayagi diarrheadir gerek karizma gerekse tasidigi anlam bu her goreceginiz saygi dict_mask= gerek okunusundaki gerekse anlam itibariyle kelimeyi sarfettiginizde goreceginiz artacaktir 0 0
# text= neyse tabii ki en guzel kelime mother father brother-in-law filan degil basbayagi diarrheadir gerek karizma gerekse tasidigi anlam bu her goreceginiz saygi label= __label__tur_Latn (new text), dict data= neyse tabii ki en guzel kelime mother father brother-in-law filan degil basbayagi diarrheadir gerek karizma gerekse tasidigi anlam bu her goreceginiz saygi dict_mask= gerek gerekse anlam goreceginiz 1 0
# text= bununla beraber teknik dallarda ogrenim gormus insanlar icin determinant eigenvalue ve constellationin gonullerdeki yeri ayridir label= __label__tur_Latn (new text), dict data= bununla beraber teknik dallarda ogrenim gormus insanlar icin determinant eigenvalue ve constellationin yeri ayridir dict_mask= bununla beraber dallarda insanlar ve gonullerdeki 0 0
# text= bununla beraber teknik dallarda ogrenim gormus insanlar icin determinant eigenvalue ve constellationin yeri ayridir label= __label__tur_Latn (new text), dict data= bununla beraber teknik dallarda ogrenim gormus insanlar icin determinant eigenvalue ve constellationin yeri ayridir dict_mask= bununla beraber dallarda insanlar ve 1 0
# text= politika alaninda ise aklima ilk gelen kelime filibusterdir politika demisken eski roma yargiclarina verilen isim olan praetor pek uzun olmamasina ragmen essiz karizmasiyla kurtariyor ayni karizmaya biraz daha yuksek sesle ulasmak icin ise unleash birebirdir label= __label__tur_Latn (new text), dict data= politika alaninda ise aklima ilk gelen kelime filibusterdir politika demisken roma yargiclarina isim praetor pek olmamasina ragmen essiz karizmasiyla ayni karizmaya daha yuksek sesle ulasmak icin ise unleash dict_mask= ise ilk eski verilen olan uzun essiz kurtariyor biraz ise birebirdir 0 0
# text= politika alaninda ise aklima ilk gelen kelime filibusterdir politika demisken roma yargiclarina isim praetor pek olmamasina ragmen essiz karizmasiyla ayni karizmaya daha yuksek sesle ulasmak icin ise unleash label= __label__tur_Latn (new text), dict data= politika alaninda ise aklima ilk gelen kelime filibusterdir politika demisken roma yargiclarina isim praetor pek olmamasina ragmen essiz karizmasiyla ayni karizmaya daha yuksek sesle ulasmak icin ise unleash dict_mask= ise ilk essiz ise 1 0
# text= politika alaninda ise aklima ilk gelen kelime filibusterdir politika demisken roma yargiclarina isim praetor pek olmamasina ragmen essiz karizmasiyla ayni karizmaya daha yuksek sesle ulasmak icin ise unleash label= __label__tur_Latn (new text), dict data= politika alaninda ise aklima gelen kelime filibusterdir politika demisken roma yargiclarina isim praetor pek olmamasina ragmen essiz karizmasiyla ayni karizmaya daha yuksek sesle ulasmak icin ise unleash dict_mask= ise ilk essiz daha sesle ise 1 1
# text= again söylemesi pek güzel ayrıca how i met your mother da ted'in ağzından duymak mümkün cheap trick in voices şarkısını söylerken label= __label__tur_Latn (new text), dict data= again pek how i met your mother da ted'in duymak mümkün cheap trick in voices dict_mask= söylemesi güzel ayrıca ted'in ağzından duymak şarkısını söylerken 0 0
# text= again pek how i met your mother da ted'in duymak mümkün cheap trick in voices label= __label__eng_Latn (new text), dict data= again pek how i met your mother da ted'in duymak mümkün cheap trick in dict_mask= your cheap trick voices 1 0
# text= self esteem olmalidir fakat tek bir kelime olmadigindan dolayi secilmesi mumkun degildir o yuzden selfless'dir nassin hoca are you getting better sen ne diyorsun so much better oldum gecedir ne uyku ne bisey sonumuz hayir olsun label= __label__tur_Latn (new text), dict data= self esteem olmalidir fakat tek kelime olmadigindan dolayi secilmesi mumkun degildir o nassin hoca are you getting better sen ne so much better oldum ne uyku ne bisey hayir olsun dict_mask= olmalidir bir olmadigindan secilmesi yuzden selfless'dir diyorsun oldum gecedir sonumuz olsun 0 0
# text= self esteem olmalidir fakat tek kelime olmadigindan dolayi secilmesi mumkun degildir o nassin hoca are you getting better sen ne so much better oldum ne uyku ne bisey hayir olsun label= __label__tur_Latn (new text), dict data= self esteem olmalidir fakat tek kelime olmadigindan dolayi secilmesi mumkun degildir o nassin hoca are you getting better sen ne so much better oldum ne uyku ne bisey hayir olsun dict_mask= olmalidir olmadigindan secilmesi oldum olsun 1 0
# text= self esteem olmalidir fakat tek kelime olmadigindan dolayi secilmesi mumkun degildir o nassin hoca are you getting better sen ne so much better oldum ne uyku ne bisey hayir olsun label= __label__tur_Latn (new text), dict data= self esteem fakat tek kelime olmadigindan dolayi secilmesi mumkun degildir o nassin hoca are you getting better sen ne so much better oldum ne uyku ne bisey hayir dict_mask= olmalidir olmadigindan secilmesi oldum olsun 1 1
# text= self esteem olmalidir fakat tek kelime olmadigindan dolayi secilmesi mumkun degildir o nassin hoca are you getting better sen ne so much better oldum ne uyku ne bisey hayir olsun label= __label__tur_Latn (new text), dict data= self esteem fakat tek kelime olmadigindan dolayi mumkun degildir o nassin hoca are you getting better sen ne so much better oldum ne uyku ne bisey hayir dict_mask= kelime olmadigindan secilmesi degildir oldum 1 2
# text= irony ve irritate irritating ve fascinating ya da ne bileyim tamamını seviyorum sanırsam listem kabardıkça kabarıyor label= __label__tur_Latn (new text), dict data= irony ve irritate irritating ve fascinating ya da ne bileyim listem kabarıyor dict_mask= ve ve tamamını seviyorum sanırsam kabardıkça kabarıyor 0 0
# text= irony ve irritate irritating ve fascinating ya da ne bileyim listem kabarıyor label= __label__tur_Latn (new text), dict data= irony ve irritate irritating ve fascinating ya da ne bileyim listem kabarıyor dict_mask= ve ve kabarıyor 1 0
# text= irony ve irritate irritating ve fascinating ya da ne bileyim listem kabarıyor label= __label__tur_Latn (new text), dict data= irony irritate irritating fascinating ya da ne bileyim listem dict_mask= ve ve kabarıyor 1 1
# text= irony ve irritate irritating ve fascinating ya da ne bileyim listem kabarıyor label= __label__tur_Latn (new text), dict data= irony irritate irritating fascinating ya da ne bileyim listem dict_mask=  1 2
# text= woody allen'a göre the most beautiful words in the english language are not i love you but it's benign ingiliz maç spikerleri golden sonra öyle bir astonishing effort diye bögürürler ki golü kendiniz atmış gibi hissedersiniz label= __label__tur_Latn (new text), dict data= woody allen'a the most beautiful words in the english language are not i love you but it's benign ingiliz golden astonishing effort diye ki golü dict_mask= göre maç spikerleri sonra öyle bir bögürürler golü kendiniz atmış gibi hissedersiniz 0 0
# text= woody allen'a the most beautiful words in the english language are not i love you but it's benign ingiliz golden astonishing effort diye ki golü label= __label__eng_Latn (new text), dict data= woody allen'a the most beautiful words in the english language are not i love you but it's benign ingiliz golden effort diye ki golü dict_mask= woody most are it's astonishing 1 0
# text= sadece adil bir kelime sade ve adil bir nevi süzgeç bir nevi sözün özü just love me just leave me just shut up daha bugun ne güzel bir kelime olduğunu düşünmüştüm kendini sözlüğe yazdırası varmış label= __label__tur_Latn (new text), dict data= adil kelime sade ve adil nevi süzgeç nevi sözün özü just love me just leave me just shut up daha bugun ne kelime kendini varmış dict_mask= sadece bir ve bir süzgeç bir sözün özü güzel bir olduğunu düşünmüştüm sözlüğe yazdırası varmış 0 0
# text= adil kelime sade ve adil nevi süzgeç nevi sözün özü just love me just leave me just shut up daha bugun ne kelime kendini varmış label= __label__tur_Latn (new text), dict data= adil kelime sade ve adil nevi süzgeç nevi sözün özü just love me just leave me just shut up daha bugun ne kelime kendini varmış dict_mask= ve süzgeç sözün özü varmış 1 0
# text= adil kelime sade ve adil nevi süzgeç nevi sözün özü just love me just leave me just shut up daha bugun ne kelime kendini varmış label= __label__tur_Latn (new text), dict data= adil kelime sade adil nevi nevi sözün özü just love me just leave me just shut up daha bugun ne kelime kendini dict_mask= ve süzgeç sözün özü daha varmış 1 1
# text= adil kelime sade ve adil nevi süzgeç nevi sözün özü just love me just leave me just shut up daha bugun ne kelime kendini varmış label= __label__tur_Latn (new text), dict data= adil kelime sade adil nevi nevi özü just love me just leave me just shut up daha bugun ne kelime kendini dict_mask= kelime sözün özü daha kelime 1 2
# text= kime göre neye göre ama bana göre crocodile nedeni bayaa uzun label= __label__tur_Latn (new text), dict data= kime neye ama bana crocodile nedeni bayaa dict_mask= göre göre göre uzun 0 0
# text= kime neye ama bana crocodile nedeni bayaa label= __label__tur_Latn (new text), dict data= kime neye ama bana crocodile nedeni bayaa dict_mask=  1 0
# text= kime neye ama bana crocodile nedeni bayaa label= __label__tur_Latn (new text), dict data= kime neye ama bana crocodile nedeni bayaa dict_mask=  1 1
# text= kime neye ama bana crocodile nedeni bayaa label= __label__tur_Latn (new text), dict data= kime neye ama bana crocodile nedeni bayaa dict_mask=  1 2
# text= immortality hatta epitaph for immortality tarzında bir sözcük öbeği daha da tadından yenilmez durumdadır label= __label__tur_Latn (new text), dict data= immortality hatta epitaph for immortality sözcük daha da dict_mask= tarzında bir sözcük öbeği tadından yenilmez durumdadır 0 0
# text= immortality hatta epitaph for immortality sözcük daha da label= __label__azj_Latn (new text), dict data= immortality hatta epitaph for immortality sözcük daha da dict_mask= sözcük 1 0
# text= immortality hatta epitaph for immortality sözcük daha da label= __label__azj_Latn (new text), dict data= immortality hatta epitaph for immortality sözcük daha da dict_mask= sözcük 1 1
# text= immortality hatta epitaph for immortality sözcük daha da label= __label__azj_Latn (new text), dict data= immortality hatta epitaph for immortality daha da dict_mask= sözcük 1 2
# text= web server tarafindan browser'a al bakiim koc nidasiyla gonderilen ve bir dahaki sefere o web sitesine o browserla girildiginde web serverina abi bana unu unu eyapmiin sen ona gore yani eklinde geri dondurulen ufak zararsiz irin ey label= __label__tur_Latn (new text), dict data= web server tarafindan browser'a al bakiim koc nidasiyla gonderilen ve dahaki sefere o web o browserla girildiginde web serverina abi bana unu unu eyapmiin sen ona gore yani geri dondurulen ufak zararsiz irin ey dict_mask= tarafindan browser'a ve bir sitesine eklinde geri 0 0
# text= web server tarafindan browser'a al bakiim koc nidasiyla gonderilen ve dahaki sefere o web o browserla girildiginde web serverina abi bana unu unu eyapmiin sen ona gore yani geri dondurulen ufak zararsiz irin ey label= __label__tur_Latn (new text), dict data= web server tarafindan browser'a al bakiim koc nidasiyla gonderilen ve dahaki sefere o web o browserla girildiginde web serverina abi bana unu unu eyapmiin sen ona gore yani geri dondurulen ufak zararsiz irin ey dict_mask= tarafindan browser'a ve geri 1 0
# text= matrix filminin birinci halkasında oracle'ın neoya the one olması matrix sistemine adapte olabilmesi ve bu sistem üzerindeki yeteneklerini arttırması için verdiği ufak dosya label= __label__tur_Latn (new text), dict data= matrix birinci neoya the one matrix sistemine adapte ve bu sistem ufak dosya dict_mask= filminin birinci halkasında oracle'ın olması olabilmesi ve üzerindeki yeteneklerini arttırması için verdiği 0 0
# text= matrix birinci neoya the one matrix sistemine adapte ve bu sistem ufak dosya label= __label__crh_Latn (new text), dict data= matrix neoya the one matrix sistemine adapte ve bu sistem ufak dict_mask= birinci ve dosya 1 0
# text= matrix birinci neoya the one matrix sistemine adapte ve bu sistem ufak dosya label= __label__crh_Latn (new text), dict data= matrix neoya the one matrix sistemine adapte ve bu sistem ufak dict_mask= ve 1 1
# text= matrix birinci neoya the one matrix sistemine adapte ve bu sistem ufak dosya label= __label__crh_Latn (new text), dict data= matrix neoya the one matrix sistemine adapte ve bu sistem ufak dict_mask= ve 1 2
# text= koala mode on durumu nedeniyle cogu zaman ceset lakabina maruz kalan mezopan'in hayatina hiperaktif hareket getiren hatun kii pek yakimilar dedirtecek kadar hayat dolu bir insan allah nice seneleri larca yillari boylesine sevgi ve nese dolu birliktelikle surdursun dedirten ciftin bir yarisi label= __label__tur_Latn (new text), dict data= koala mode on durumu cogu zaman ceset lakabina maruz kalan mezopan'in hayatina hareket getiren hatun kii pek yakimilar hayat dolu insan allah nice seneleri larca yillari sevgi ve nese dolu surdursun ciftin yarisi dict_mask= durumu nedeniyle zaman mezopan'in hiperaktif getiren dedirtecek kadar bir seneleri boylesine ve birliktelikle surdursun dedirten ciftin bir 0 0
# text= koala mode on durumu cogu zaman ceset lakabina maruz kalan mezopan'in hayatina hareket getiren hatun kii pek yakimilar hayat dolu insan allah nice seneleri larca yillari sevgi ve nese dolu surdursun ciftin yarisi label= __label__tur_Latn (new text), dict data= koala mode on durumu cogu zaman ceset lakabina maruz kalan mezopan'in hayatina hareket getiren hatun kii pek yakimilar hayat dolu insan allah nice seneleri larca yillari sevgi ve nese dolu surdursun ciftin yarisi dict_mask= durumu zaman mezopan'in getiren seneleri ve surdursun ciftin 1 0
# text= subwaydeki tadına doyum olmayan cookielerin aynısından caddebostan burger kingde de yapıyolar artık label= __label__tur_Latn (new text), dict data= subwaydeki doyum olmayan cookielerin caddebostan burger kingde de dict_mask= subwaydeki tadına olmayan cookielerin aynısından yapıyolar artık 0 0
# ...
# text= oops i did it again i played with your heart got lost in the game oh baby baby label= __label__eng_Latn (new text), dict data= oops i did it again i with your heart got in the game oh baby baby dict_mask= did played your lost 0 0
# text= oops i did it again i with your heart got in the game oh baby baby label= __label__pcm_Latn (new text), dict data= oops i did it i with your heart got in the game oh dict_mask= again your oh baby baby 1 0
# text= oops i did it again i with your heart got in the game oh baby baby label= __label__pcm_Latn (new text), dict data= oops i did it i with your heart got in the game dict_mask= your got oh 1 1
# text= oops i did it again i with your heart got in the game oh baby baby label= __label__pcm_Latn (new text), dict data= oops i did it i with your heart got in the game dict_mask= your heart got 1 2
# text= this is the main thing u should know abt life it makes u stronger thn before and which will lead to succed label= __label__eng_Latn (new text), dict data= this is the main thing u should know abt life it u stronger thn before and which will lead to dict_mask= is main should know makes before and will lead succed 0 0
# text= this is the main thing u should know abt life it u stronger thn before and which will lead to label= __label__eng_Latn (new text), dict data= this is the main thing u should know abt life it u stronger thn before and which will lead to dict_mask= is main should know before and will lead 1 0
# text= so all the photos i took today are magically not in my phone what sorcery is this label= __label__eng_Latn (new text), dict data= so all the photos i took today are not in my phone what is this dict_mask= took are magically sorcery is 0 0
# text= so all the photos i took today are not in my phone what is this label= __label__eng_Latn (new text), dict data= so all the photos i took today are not in my phone what is this dict_mask= took are is 1 0
# text= so all the photos i took today are not in my phone what is this label= __label__eng_Latn (new text), dict data= so all the photos i took today are not in my phone what is this dict_mask= took today are is 1 1
# text= so all the photos i took today are not in my phone what is this label= __label__eng_Latn (new text), dict data= so all the photos i today are not in my phone what is this dict_mask= photos took today are phone is this 1 2
# text= already asked i don't know no formalities now waiting for your answer label= __label__eng_Latn (new text), dict data= already i don't know no formalities now waiting for your dict_mask= already asked don't know formalities waiting your answer 0 0
# text= already i don't know no formalities now waiting for your label= __label__eng_Latn (new text), dict data= already i don't know no formalities now waiting for your dict_mask= already don't know formalities waiting your 1 0
# text= actually people are afraid to even talk to u because of yur caustic nature or at least i am afraid of u label= __label__eng_Latn (new text), dict data= people are to even talk to u because of yur caustic nature or at least i am of u dict_mask= actually are afraid caustic afraid 0 0
# text= people are to even talk to u because of yur caustic nature or at least i am of u label= __label__eng_Latn (new text), dict data= people are to even talk to u because of yur caustic nature or at least i am of u dict_mask= are caustic 1 0
# text= people are to even talk to u because of yur caustic nature or at least i am of u label= __label__eng_Latn (new text), dict data= people are to even talk to u because of yur nature or at least i am of u dict_mask= are caustic 1 1
# text= people are to even talk to u because of yur caustic nature or at least i am of u label= __label__eng_Latn (new text), dict data= people are to even talk to u because of yur nature or at least i am of u dict_mask= are 1 2
# text= graet if you don't mind send u mail after couple of days hoping for further talk via mails okay label= __label__eng_Latn (new text), dict data= graet if you don't mind send u mail after couple of days hoping for further talk via mails okay dict_mask= don't days hoping further 0 0
# text= graet if you don't mind send u mail after couple of days hoping for further talk via mails okay label= __label__eng_Latn (new text), dict data= graet if you don't mind send u mail after couple of days hoping for further talk via mails okay dict_mask= don't days hoping further 1 0
# text= does your preach u to call every other sane person who is not you an idiot nd a book other than by cynic filthy book label= __label__eng_Latn (new text), dict data= does your preach u to call every other sane person who is not you an idiot nd a book other than by cynic filthy book dict_mask= your call is filthy 0 0
# text= does your preach u to call every other sane person who is not you an idiot nd a book other than by cynic filthy book label= __label__eng_Latn (new text), dict data= does your preach u to call every other sane person who is not you an idiot nd a book other than by cynic filthy book dict_mask= your call is filthy 1 0
# text= does your preach u to call every other sane person who is not you an idiot nd a book other than by cynic filthy book label= __label__eng_Latn (new text), dict data= does your preach u to call every other sane person who is not you an idiot nd a book other than by cynic filthy book dict_mask= your call is filthy 1 1
# text= does your preach u to call every other sane person who is not you an idiot nd a book other than by cynic filthy book label= __label__eng_Latn (new text), dict data= does your preach u to every other sane person who is not you an idiot nd a book other than by cynic book dict_mask= does your call is book filthy book 1 2
# text= healing those hidden pains is not so easy and hurt all the day and night u need to be strong which is only weapon to cure label= __label__eng_Latn (new text), dict data= healing those hidden pains is not so easy and hurt all the day and night u need to be strong which is only weapon to cure dict_mask= pains is and and is 0 0
# text= healing those hidden pains is not so easy and hurt all the day and night u need to be strong which is only weapon to cure label= __label__eng_Latn (new text), dict data= healing those hidden pains is not so easy and hurt all the day and night u need to be strong which is only weapon to cure dict_mask= pains is and and is 1 0
# text= healing those hidden pains is not so easy and hurt all the day and night u need to be strong which is only weapon to cure label= __label__eng_Latn (new text), dict data= healing those hidden pains is not so easy and hurt all the day and night u need to be strong which is only weapon to cure dict_mask= pains is and and is 1 1
# text= healing those hidden pains is not so easy and hurt all the day and night u need to be strong which is only weapon to cure label= __label__eng_Latn (new text), dict data= healing those hidden pains is not so easy hurt all the day night u need to be strong which is only weapon to cure dict_mask= pains is and and is 1 2
# text= god i typed mistake number will u send me ur number then label= __label__eng_Latn (new text), dict data= god i mistake number will u send me ur number then dict_mask= typed mistake will 0 0
# text= god i mistake number will u send me ur number then label= __label__eng_Latn (new text), dict data= god i mistake number will u send me ur number then dict_mask= mistake will 1 0
# text= god i mistake number will u send me ur number then label= __label__eng_Latn (new text), dict data= god i mistake number will u send me ur number then dict_mask= mistake will 1 1
# text= god i mistake number will u send me ur number then label= __label__eng_Latn (new text), dict data= god i mistake number u send me ur number then dict_mask= mistake number will number then 1 2
# text= anywhere frm hell to heaven corner to straight mountains to plain land mysterious journey of my lyf label= __label__eng_Latn (new text), dict data= anywhere frm hell to heaven corner to straight mountains to plain land journey of my lyf dict_mask= heaven straight mountains mysterious journey 0 0
# text= anywhere frm hell to heaven corner to straight mountains to plain land journey of my lyf label= __label__eng_Latn (new text), dict data= anywhere frm hell to heaven corner to straight mountains to plain land journey of my lyf dict_mask= heaven straight mountains journey 1 0
# text= if you go by one 's own opinion i am the biggest bore of this whole world label= __label__eng_Latn (new text), dict data= if you go by one 's own opinion i am the bore of this whole world dict_mask= own biggest 0 0
# text= if you go by one 's own opinion i am the bore of this whole world label= __label__eng_Latn (new text), dict data= if you go by one 's own opinion i am the bore of this whole world dict_mask= own 1 0
# text= if you go by one 's own opinion i am the bore of this whole world label= __label__eng_Latn (new text), dict data= if you go by one 's opinion i am the bore of this whole world dict_mask= own 1 1
# text= if you go by one 's own opinion i am the bore of this whole world label= __label__eng_Latn (new text), dict data= if you go by one 's opinion i am the bore of this whole world dict_mask= this 1 2
# text= haha somehow i've encountered this smiley for the first time from your status/post i remember you when i see label= __label__eng_Latn (new text), dict data= haha somehow i've this smiley for the first time your status/post i remember you when i see dict_mask= encountered first from your remember 0 0
# text= haha somehow i've this smiley for the first time your status/post i remember you when i see label= __label__eng_Latn (new text), dict data= haha somehow i've this smiley for the first time your status/post i remember you when i see dict_mask= first your remember 1 0
# text= haha somehow i've this smiley for the first time your status/post i remember you when i see label= __label__eng_Latn (new text), dict data= haha somehow i've this smiley for the first time your status/post i you when i see dict_mask= smiley first your remember 1 1
# text= of course remeber ask for autograph if it happen a photoshot also hope u don't mind see u label= __label__eng_Latn (new text), dict data= of course remeber ask for autograph if it happen a photoshot also hope u don't mind see u dict_mask= ask photoshot also don't 0 0
# text= of course remeber ask for autograph if it happen a photoshot also hope u don't mind see u label= __label__eng_Latn (new text), dict data= of course remeber ask for autograph if it happen a photoshot also hope u don't mind see u dict_mask= ask photoshot also don't 1 0
# text= dear someone i remember when we used to talk everyday i miss that label= __label__eng_Latn (new text), dict data= dear someone i remember when we used to talk everyday i miss that dict_mask= dear remember used miss 0 0
# text= dear someone i remember when we used to talk everyday i miss that label= __label__eng_Latn (new text), dict data= dear someone i remember when we used to talk everyday i miss that dict_mask= dear remember used miss 1 0
# text= one never gets tired of watching it no matter how many times you do label= __label__eng_Latn (new text), dict data= one never tired of watching it no matter how many times you do dict_mask= never gets 0 0
# text= one never tired of watching it no matter how many times you do label= __label__eng_Latn (new text), dict data= one never tired of watching it no matter how many times you do dict_mask= never 1 0
# text= one never tired of watching it no matter how many times you do label= __label__eng_Latn (new text), dict data= one tired of watching it no matter how many times you do dict_mask= never 1 1
# text= one never tired of watching it no matter how many times you do label= __label__eng_Latn (new text), dict data= one tired of watching it no matter how many times you do dict_mask=  1 2
# text= they butcher him and his whole family haha label= __label__eng_Latn (new text), dict data= they butcher him and his whole family haha dict_mask= and 0 0
# text= they butcher him and his whole family haha label= __label__eng_Latn (new text), dict data= they butcher him and his whole family haha dict_mask= and 1 0
# text= they butcher him and his whole family haha label= __label__eng_Latn (new text), dict data= they butcher him and his whole family haha dict_mask= and his family 1 1
# text= they butcher him and his whole family haha label= __label__eng_Latn (new text), dict data= they butcher him his whole family haha dict_mask= and his family 1 2
# text= even her voice is enough to make me fall for her all over again label= __label__eng_Latn (new text), dict data= even her voice is enough to make me fall for her all over again dict_mask= voice is enough over 0 0
# text= even her voice is enough to make me fall for her all over again label= __label__eng_Latn (new text), dict data= even her voice is enough to make me fall for her all over again dict_mask= voice is enough over 1 0
# text= even her voice is enough to make me fall for her all over again label= __label__eng_Latn (new text), dict data= even her is enough to make me fall for her all over again dict_mask= voice is enough over 1 1
# text= even her voice is enough to make me fall for her all over again label= __label__eng_Latn (new text), dict data= even her is enough to make me fall for her all again dict_mask= is enough over 1 2
# text= look at the brighter side we aren't playing for days and this might be our longest unbeaten run label= __label__eng_Latn (new text), dict data= look at the brighter side we for days and this might be our longest unbeaten run dict_mask= brighter aren't playing days and might longest 0 0
# text= look at the brighter side we for days and this might be our longest unbeaten run label= __label__eng_Latn (new text), dict data= look at the brighter side we for days and this might be our longest unbeaten run dict_mask= brighter days and might longest 1 0
# text= no idea you are too high tc n stay safe goodnight” label= __label__eng_Latn (new text), dict data= no idea you are too high tc n stay safe goodnight” dict_mask= are 0 0
# text= no idea you are too high tc n stay safe goodnight” label= __label__eng_Latn (new text), dict data= no idea you are too high tc n stay safe goodnight” dict_mask= are 1 0
# text= no idea you are too high tc n stay safe goodnight” label= __label__eng_Latn (new text), dict data= no idea you are too high tc n stay safe goodnight” dict_mask= are 1 1
# text= no idea you are too high tc n stay safe goodnight” label= __label__eng_Latn (new text), dict data= no idea you are too high tc n stay safe goodnight” dict_mask= are high safe 1 2
# text= her words spoke hatred and pity he heard them read them smiled and said to himself this is how people never change label= __label__eng_Latn (new text), dict data= her words hatred and pity he them read them and to himself this is how people never change dict_mask= spoke and heard smiled and said himself is never 0 0
# text= her words hatred and pity he them read them and to himself this is how people never change label= __label__eng_Latn (new text), dict data= her words hatred and pity he them read them and to himself this is how people never change dict_mask= and and himself is never 1 0
# text= i wish the same lady how u doing label= __label__kha_Latn (new text), dict data= i wish the same lady how u doing dict_mask= u 0 0
# text= i wish the same lady how u doing label= __label__kha_Latn (new text), dict data= i wish the same lady how u doing dict_mask= u 1 0
# text= i wish the same lady how u doing label= __label__kha_Latn (new text), dict data= i wish the same lady how u doing dict_mask= u 1 1
# text= i wish the same lady how u doing label= __label__kha_Latn (new text), dict data= i wish the same lady how doing dict_mask= u 1 2

# %% [markdown]
# MONO-ENGLISH EVAL

# %%
subset_e_om  = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_e["True Labels"].values)]    # Mono English

em_e_om, pm_e_om = em_pm_mono(subset_e_om["True Labels"], subset_e_om["Pred"])

# Output hasil
print(f"#EM: {em_e_om}")
print(f"#PM: {pm_e_om}")
# Out:
# #EM: 447
# #PM: 449

# %% [markdown]
# TURKISH-ENGLISH EVAL

# %%
subset_te_om = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_te["True Labels"].values)]
subset_t_om  = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_t["True Labels"].values)]

# CS Turkish–English: EM / PM
em_te_om, pm_te_om = em_pm_cs(subset_te_om["True Labels"], subset_te_om["Pred"])

# FP 
fp_te_om = count_fp(subset_te_om["True Labels"], subset_te_om["Pred"])

# Mono Turkish: EM / PM
em_t_om, pm_t_om = em_pm_mono(subset_t_om["True Labels"], subset_t_om["Pred"])

# Output result
print(f"#EM: {em_te_om}")
print(f"#PM: {pm_te_om}")
print(f"#FP: {fp_te_om}")
# Out:
# #EM: 58
# #PM: 301
# #FP: 32

# %% [markdown]
# BASQUE-SPANISH EVAL

# %%
subset_bs_om = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_bs["True Labels"].values)]
subset_b_om  = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_b["True Labels"].values)]
subset_s_om  = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_s["True Labels"].values)]

# CS Basque–Spanish: EM / PM
em_bs_om, pm_bs_om = em_pm_cs(subset_bs_om["True Labels"], subset_bs_om["Pred"])

# FP 
fp_bs_om = count_fp(subset_bs_om["True Labels"], subset_bs_om["Pred"])

# Mono Basque: EM / PM
em_b_om, pm_b_om = em_pm_mono(subset_b_om["True Labels"], subset_b_om["Pred"])

# Mono Spanish: EM / PM
em_s_om, pm_s_om = em_pm_mono(subset_s_om["True Labels"], subset_s_om["Pred"])

print(f"#EM: {em_bs_om}")
print(f"#PM: {pm_bs_om}")
print(f"#FP: {fp_bs_om}")
# Out:
# #EM: 55
# #PM: 413
# #FP: 18

# %% [markdown]
# HINDI-ENGLISH EVAL

# %%
subset_he_om = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_he["True Labels"].values)]
subset_h_om  = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_h["True Labels"].values)]
subset_e_om  = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_e["True Labels"].values)]

# EM / PM untuk CS Hindi–English
em_he_om, pm_he_om = em_pm_cs(subset_he_om["True Labels"], subset_he_om["Pred"])

# FP 
fp_he_om = count_fp(subset_he_om["True Labels"], subset_he_om["Pred"])

# Mono Hindi: EM / PM
em_h_om, pm_h_om = em_pm_mono(subset_h_om["True Labels"], subset_h_om["Pred"])

print(f"#EM: {em_he_om}")
print(f"#PM: {pm_he_om}")
print(f"#FP: {fp_he_om}")
# Out:
# #EM: 0
# #PM: 81
# #FP: 14

# %% [markdown]
# NEPALI-ENGLISH EVAL

# %%
subset_ne_om = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_ne["True Labels"].values)]
subset_n_om  = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_n["True Labels"].values)]
subset_e_om  = df_eval_om[df_eval_om["True Labels"].apply(lambda x: x in df_e["True Labels"].values)]

# EM / PM untuk CS Nepali–English
em_ne_om, pm_ne_om = em_pm_cs(subset_ne_om["True Labels"], subset_ne_om["Pred"])

# FP 
fp_ne_om = count_fp(subset_ne_om["True Labels"], subset_ne_om["Pred"])

# Mono Nepali: EM / PM
em_n_om, pm_n_om = em_pm_mono(subset_n_om["True Labels"], subset_n_om["Pred"])

print(f"#EM: {em_ne_om}")
print(f"#PM: {pm_ne_om}")
print(f"#FP: {fp_ne_om}")
# Out:
# #EM: 0
# #PM: 83
# #FP: 37

# %% [markdown]
# 4.GlotLID with MaskLID

# %%
# masklid is the name of masklid.py
from masklid import MaskLID


gm_model = MaskLID(glot_model_path, languages = flores_glotlid)

def gm_lid(text):
    
    prediction = gm_model.predict_codeswitch(text, beta = 15 , alpha = 3, max_lambda = 2, min_length = 20, min_prob = 0.90, max_retry=3, alpha_step_increase = 3, beta_step_increase = 5)
    
    return set(prediction.keys())
    
def apply_gm_lid(df):
            
    df['Pred'] = df['Text'].apply(gm_lid)
        
    return df

# %%
# Apply to all data
df_eval_gm = apply_gm_lid(df_eval_gm)  

# Normalize the ground truth label column to set
df_eval_gm["True Labels"] = df_eval_gm["True Labels"].apply(lambda x: set(x) if isinstance(x, list) or isinstance(x, set) else set(x.split()))

# %% [markdown]
# ENGLISH-ONLY EVAL

# %%
subset_e_gm  = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_e["True Labels"].values)]
em_e_gm, pm_e_gm = em_pm_mono(subset_e_gm["True Labels"], subset_e_gm["Pred"])

print(f"#EM: {em_e_gm}")
print(f"#PM: {pm_e_gm}")
# Out:
# #EM: 450
# #PM: 464

# %% [markdown]
# TURKISH-ENGLISH EVAL

# %%
subset_te_gm = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_te["True Labels"].values)]
subset_t_gm  = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_t["True Labels"].values)]

em_te_gm, pm_te_gm = em_pm_cs(subset_te_gm["True Labels"], subset_te_gm["Pred"])

fp_te_gm = count_fp(subset_te_gm["True Labels"], subset_te_gm["Pred"])

em_t_gm, pm_t_gm = em_pm_mono(subset_t_gm["True Labels"], subset_t_gm["Pred"])

print(f"#EM: {em_te_gm}")
print(f"#PM: {pm_te_gm}")
print(f"#FP: {fp_te_gm}")
# Out:
# #EM: 74
# #PM: 315
# #FP: 19

# %% [markdown]
# BASQ-SPANISH EVAL

# %%
subset_bs_gm = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_bs["True Labels"].values)]
subset_b_gm  = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_b["True Labels"].values)]
subset_s_gm  = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_s["True Labels"].values)]

em_bs_gm, pm_bs_gm = em_pm_cs(subset_bs_gm["True Labels"], subset_bs_gm["Pred"])

fp_bs_gm = count_fp(subset_bs_gm["True Labels"], subset_bs_gm["Pred"])

em_b_gm, pm_b_gm = em_pm_mono(subset_b_gm["True Labels"], subset_b_gm["Pred"])

em_s_gm, pm_s_gm = em_pm_mono(subset_s_gm["True Labels"], subset_s_gm["Pred"])

print(f"#EM: {em_bs_gm}")
print(f"#PM: {pm_bs_gm}")
print(f"#FP: {fp_bs_gm}")
# Out:
# #EM: 47
# #PM: 423
# #FP: 10

# %% [markdown]
# HINDI-ENGLISH EVAL

# %%
subset_he_gm = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_he["True Labels"].values)]
subset_h_gm  = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_h["True Labels"].values)]
subset_e_gm  = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_e["True Labels"].values)]

em_he_gm, pm_he_gm = em_pm_cs(subset_he_gm["True Labels"], subset_he_gm["Pred"])

fp_he_gm = count_fp(subset_he_gm["True Labels"], subset_he_gm["Pred"])

em_h_gm, pm_h_gm = em_pm_mono(subset_h_gm["True Labels"], subset_h_gm["Pred"])

print(f"#EM: {em_he_gm}")
print(f"#PM: {pm_he_gm}")
print(f"#FP: {fp_he_gm}")
# Out:
# #EM: 0
# #PM: 76
# #FP: 23

# %% [markdown]
# NEPALI-ENGLISH EVAL

# %%
subset_ne_gm = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_ne["True Labels"].values)]
subset_n_gm  = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_n["True Labels"].values)]
subset_e_gm  = df_eval_gm[df_eval_gm["True Labels"].apply(lambda x: x in df_e["True Labels"].values)]

em_ne_gm, pm_ne_gm = em_pm_cs(subset_ne_gm["True Labels"], subset_ne_gm["Pred"])

fp_ne_gm = count_fp(subset_ne_gm["True Labels"], subset_ne_gm["Pred"])

em_n_gm, pm_n_gm = em_pm_mono(subset_n_gm["True Labels"], subset_n_gm["Pred"])

print(f"#EM: {em_ne_gm}")
print(f"#PM: {pm_ne_gm}")
print(f"#FP: {fp_ne_gm}")
# Out:
# #EM: 0
# #PM: 115
# #FP: 25

# %% [markdown]
# FINAL EVAL

# %%
import pandas as pd
from IPython.display import display

# Urutan set
sets = [
    "CS Turkish-English", "CS Basq Spanish", "CS Hindi English", "CS Nepali English",
    "Single Basq", "Single Spanish", "Single Turkish", "Single Hindi", "Single Nepali", "Single English"
]
s_values = [len(df_te), len(df_bs), len(df_he), len(df_ne), len(df_b), len(df_s), len(df_t), len(df_h), len(df_n), len(df_e)]

# MultiIndex columns
columns = pd.MultiIndex.from_tuples([
    ("", "Set"),
    ("", "#S"),
    ("Baseline + MaskLID", "GlotLID EM/PM"),
    ("Baseline + MaskLID", "OpenLID EM/PM"),
    ("Baseline", "GlotLID & GlotLID #FP"),
    ("Baseline", "OpenLID & MaskLID #FP"),
    ("Baseline", "GlotLID EM/PM"),
    ("Baseline", "OpenLID EM/PM"),
    ("Baseline", "OpenLID #FP"),
    ("Baseline", "GlotLID #FP"),
])

# Baris data: 10 baris sesuai sets
rows = list(zip(
    sets,
    s_values,
    
    # GlotLID + MaskLID EM/PM
    [f"{em_te_gm}/{pm_te_gm}", f"{em_bs_gm}/{pm_bs_gm}", f"{em_he_gm}/{pm_he_gm}", f"{em_ne_gm}/{pm_ne_gm}",
     f"{em_b_gm}/{pm_b_gm}", f"{em_s_gm}/{pm_s_gm}", f"{em_t_gm}/{pm_t_gm}", f"{em_h_gm}/{pm_h_gm}", f"{em_n_gm}/{pm_n_gm}", f"{em_e_gm}/{pm_e_gm}"],

    # OpenLID + MaskLID EM/PM
    [f"{em_te_om}/{pm_te_om}", f"{em_bs_om}/{pm_bs_om}", f"{em_he_om}/{pm_he_om}", f"{em_ne_om}/{pm_ne_om}",
     f"{em_b_om}/{pm_b_om}", f"{em_s_om}/{pm_s_om}", f"{em_t_om}/{pm_t_om}", f"{em_h_om}/{pm_h_om}", f"{em_n_om}/{pm_n_om}", f"{em_e_om}/{pm_e_om}"],

    # GlotLID FP (GlotLID + MaskLID pipeline)
    [fp_te_gm, fp_bs_gm, fp_he_gm, fp_ne_gm, fp_bs_gm],

    # OpenLID FP (OpenLID + MaskLID pipeline)
    [fp_te_om, fp_bs_om, fp_he_om, fp_ne_om, fp_bs_om],

    # GlotLID EM/PM (tanpa MaskLID)
    [f"{em_te_g}/{pm_te_g}", f"{em_bs_g}/{pm_bs_g}", f"{em_he_g}/{pm_he_g}", f"{em_ne_g}/{pm_ne_g}",
     f"{em_b_g}/{pm_b_g}", f"{em_s_g}/{pm_s_g}", f"{em_t_g}/{pm_t_g}", f"{em_h_g}/{pm_h_g}", f"{em_n_g}/{pm_n_g}", f"{em_e_g}/{pm_e_g}"],

    # OpenLID EM/PM (tanpa MaskLID)
    [f"{em_te_o}/{pm_te_o}", f"{em_bs_o}/{pm_bs_o}", f"{em_he_o}/{pm_he_o}", f"{em_ne_o}/{pm_ne_o}",
     f"{em_b_o}/{pm_b_o}", f"{em_s_o}/{pm_s_o}", f"{em_t_o}/{pm_t_o}", f"{em_h_o}/{pm_h_o}", f"{em_n_o}/{pm_n_o}", f"{em_e_o}/{pm_e_o}"],

    # OpenLID #FP
    [fp_te_o, fp_bs_o, fp_he_o, fp_ne_o, fp_bs_o],

    # GlotLID #FP
    [fp_te_g, fp_bs_g, fp_he_g, fp_ne_g, fp_bs_g]
))

# Buat dan tampilkan DataFrame
df_paper_style = pd.DataFrame(rows, columns=columns)
pd.set_option("display.width", 200)
display(df_paper_style)
# Out:
#                            Baseline + MaskLID                            Baseline
#                   Set   #S      GlotLID EM/PM OpenLID EM/PM GlotLID & GlotLID #FP OpenLID & MaskLID #FP GlotLID EM/PM OpenLID EM/PM OpenLID #FP GlotLID #FP
# 0  CS Turkish-English  339             74/315        58/301                    19                    32         4/330         4/323           8           3
# 1     CS Basq Spanish  446             47/423        55/413                    10                    18         9/430         9/423           6           1
# 2    CS Hindi English  235               0/76          0/81                    23                    14          0/84          0/80           2           4
# 3   CS Nepali English  623              0/115          0/83                    25                    37         0/118          0/93           4           7
# 4         Single Basq  357            354/354       355/355                    10                    18       353/353       355/355           6           1
